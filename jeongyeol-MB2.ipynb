# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import ListedColormap

# %%
import pandas as pd

# 출력 옵션 설정
pd.set_option('display.max_rows', 50)  # 모든 행 출력
pd.set_option('display.max_columns', 50)  # 모든 열 출력

# 옵션 원래대로 되돌리기
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')

# %% [markdown]
# # 데이터 불러오고 모든 값이 null인 컬럼과 모든 값이 동일한 컬럼 제거

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame()
for chunk in pd.read_csv("../ssd_data/combined_by_diskmodel/combined_MB2.csv", chunksize=100000):
    data = pd.concat([data, chunk], ignore_index=True)
data

# 데이터를 시간 순서대로 정렬 ('ds' 컬럼을 기준으로)
data = data.sort_values(by='ds')
del(data['index'])
data
# Out:
#          disk_id        ds model  n_1  r_1    n_5  r_5   n_9      r_9  n_12  \
# 0            100  20190101   MB2  NaN  NaN  100.0  0.0  96.0  20012.0  99.0
# 29067      34365  20190101   MB2  NaN  NaN  100.0  0.0  95.0  20881.0  99.0
# 29068      34382  20190101   MB2  NaN  NaN  100.0  0.0  96.0  17911.0  99.0
# 29069      34397  20190101   MB2  NaN  NaN  100.0  0.0  95.0  20272.0  99.0
# 29070      34418  20190101   MB2  NaN  NaN  100.0  0.0  95.0  20562.0  99.0
# ...          ...       ...   ...  ...  ...    ...  ...   ...      ...   ...
# 7725412    21806  20190630   MB2  NaN  NaN  100.0  0.0  95.0  24987.0  99.0
# 7725413    21811  20190630   MB2  NaN  NaN  100.0  0.0  93.0  31438.0  98.0
# 7725414    21818  20190630   MB2  NaN  NaN  100.0  0.0  93.0  31443.0  98.0
# 7725406    21658  20190630   MB2  NaN  NaN  100.0  0.0  95.0  23549.0  99.0
# 7754102     9989  20190630   MB2  NaN  NaN  100.0  0.0  95.0  24422.0  99.0
#
#            r_12  n_170  r_170  n_171  r_171  n_172  r_172  n_173  r_173  \
# 0          57.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 29067      21.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 29068      21.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 29069      12.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 29070      33.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7725412    20.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7725413  1014.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7725414  1057.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7725406    28.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7754102    11.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#          n_174  r_174  n_177  r_177  n_180    r_180  ...  n_197  r_197  n_198  \
# 0          NaN    NaN   99.0   20.0  100.0  15238.0  ...  100.0    0.0    NaN
# 29067      NaN    NaN   98.0  702.0  100.0  15301.0  ...  100.0    0.0    NaN
# 29068      NaN    NaN   98.0  711.0  100.0  15310.0  ...  100.0    0.0    NaN
# 29069      NaN    NaN   99.0  218.0  100.0  15292.0  ...  100.0    0.0    NaN
# 29070      NaN    NaN   98.0  394.0  100.0  15341.0  ...  100.0    0.0    NaN
# ...        ...    ...    ...    ...    ...      ...  ...    ...    ...    ...
# 7725412    NaN    NaN   99.0  285.0  100.0  15310.0  ...  100.0    0.0    NaN
# 7725413    NaN    NaN   98.0  592.0  100.0  15215.0  ...  100.0    0.0    NaN
# 7725414    NaN    NaN   98.0  602.0  100.0  15284.0  ...  100.0    0.0    NaN
# 7725406    NaN    NaN   99.0   68.0  100.0  15334.0  ...  100.0    0.0    NaN
# 7754102    NaN    NaN   99.0  223.0  100.0  15289.0  ...  100.0    0.0    NaN
#
#          r_198  n_199  r_199  n_206  r_206  n_233  r_233  n_241         r_241  \
# 0          NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  6.916669e+10
# 29067      NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  1.013831e+12
# 29068      NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  2.286572e+12
# 29069      NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  6.670700e+11
# 29070      NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  4.731031e+11
# ...        ...    ...    ...    ...    ...    ...    ...    ...           ...
# 7725412    NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  7.368685e+11
# 7725413    NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  1.381409e+12
# 7725414    NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  1.403214e+12
# 7725406    NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  2.474254e+11
# 7754102    NaN  100.0    0.0    NaN    NaN    NaN    NaN   99.0  3.281347e+11
#
#          n_242         r_242  n_244  r_244  n_245    r_245  n_175  r_175  \
# 0         99.0  4.377350e+09  100.0    0.0  100.0  65535.0    NaN    NaN
# 29067     99.0  6.677894e+11  100.0    0.0  100.0  65535.0    NaN    NaN
# 29068     99.0  4.380341e+11  100.0    0.0  100.0  65535.0    NaN    NaN
# 29069     99.0  4.956816e+11  100.0    0.0  100.0  65535.0    NaN    NaN
# 29070     99.0  1.697450e+10  100.0    0.0  100.0  65535.0    NaN    NaN
# ...        ...           ...    ...    ...    ...      ...    ...    ...
# 7725412   99.0  1.350921e+12  100.0    0.0  100.0  65535.0    NaN    NaN
# 7725413   99.0  4.058834e+11  100.0    0.0  100.0  65535.0    NaN    NaN
# 7725414   99.0  4.113683e+11  100.0    0.0  100.0  65535.0    NaN    NaN
# 7725406   99.0  1.035013e+12  100.0    0.0  100.0  65535.0    NaN    NaN
# 7754102   99.0  4.228293e+11  100.0    0.0  100.0  65535.0    NaN    NaN
#
#          n_232  r_232  label  n_211  r_211
# 0          NaN    NaN      0    NaN    NaN
# 29067      NaN    NaN      0    NaN    NaN
# 29068      NaN    NaN      0    NaN    NaN
# 29069      NaN    NaN      0    NaN    NaN
# 29070      NaN    NaN      0    NaN    NaN
# ...        ...    ...    ...    ...    ...
# 7725412    NaN    NaN      0    NaN    NaN
# 7725413    NaN    NaN      0    NaN    NaN
# 7725414    NaN    NaN      0    NaN    NaN
# 7725406    NaN    NaN      0    NaN    NaN
# 7754102    NaN    NaN      0    NaN    NaN
#
# [7754103 rows x 72 columns]

# %%
data.shape
# Out:
# (7754103, 72)

# %%
data.columns
# Out:
# Index(['disk_id', 'ds', 'model', 'n_1', 'r_1', 'n_5', 'r_5', 'n_9', 'r_9',
#        'n_12', 'r_12', 'n_170', 'r_170', 'n_171', 'r_171', 'n_172', 'r_172',
#        'n_173', 'r_173', 'n_174', 'r_174', 'n_177', 'r_177', 'n_180', 'r_180',
#        'n_181', 'r_181', 'n_182', 'r_182', 'n_183', 'r_183', 'n_184', 'r_184',
#        'n_187', 'r_187', 'n_188', 'r_188', 'n_190', 'r_190', 'n_192', 'r_192',
#        'n_194', 'r_194', 'n_195', 'r_195', 'n_196', 'r_196', 'n_197', 'r_197',
#        'n_198', 'r_198', 'n_199', 'r_199', 'n_206', 'r_206', 'n_233', 'r_233',
#        'n_241', 'r_241', 'n_242', 'r_242', 'n_244', 'r_244', 'n_245', 'r_245',
#        'n_175', 'r_175', 'n_232', 'r_232', 'label', 'n_211', 'r_211'],
#       dtype='object')

# %% [markdown]
# Null값으로 이루어진 열 제거

# %%
# null값이 있는 열을 제거하는 코드
def remove_null_columns(df):
    # null인 컬럼을 확인하고, 모든 값이 null인 컬럼을 찾습니다.
    null_columns = df.columns[df.isnull().all()]
    
    # 모든 값이 null인 컬럼을 DataFrame에서 제거합니다.
    df = df.drop(null_columns, axis=1)
    
    return df

# %%
data = remove_null_columns(data)
data.shape
# Out:
# (7754103, 40)

# %%
data.columns
# Out:
# Index(['disk_id', 'ds', 'model', 'n_5', 'r_5', 'n_9', 'r_9', 'n_12', 'r_12',
#        'n_177', 'r_177', 'n_180', 'r_180', 'n_181', 'r_181', 'n_182', 'r_182',
#        'n_183', 'r_183', 'n_184', 'r_184', 'n_187', 'r_187', 'n_190', 'r_190',
#        'n_195', 'r_195', 'n_197', 'r_197', 'n_199', 'r_199', 'n_241', 'r_241',
#        'n_242', 'r_242', 'n_244', 'r_244', 'n_245', 'r_245', 'label'],
#       dtype='object')

# %% [markdown]
# 단일값으로만 이루어진 행 제거

# %%
def remove_single_value_columns(df):
    single_value_cols = []
    for col in df.columns:
        unique_values = df[col].nunique()
        if unique_values == 1:
            single_value_cols.append(col)
    print(single_value_cols)
    df_filtered = df.drop(single_value_cols, axis=1)
    return df_filtered

# %%
data = remove_single_value_columns(data)
# Out:
# ['model', 'n_184', 'r_184', 'n_197', 'r_197', 'n_244', 'n_245', 'r_245']

# %%
data
# Out:
#          disk_id        ds    n_5  r_5   n_9      r_9  n_12    r_12  n_177  \
# 0            100  20190101  100.0  0.0  96.0  20012.0  99.0    57.0   99.0
# 29067      34365  20190101  100.0  0.0  95.0  20881.0  99.0    21.0   98.0
# 29068      34382  20190101  100.0  0.0  96.0  17911.0  99.0    21.0   98.0
# 29069      34397  20190101  100.0  0.0  95.0  20272.0  99.0    12.0   99.0
# 29070      34418  20190101  100.0  0.0  95.0  20562.0  99.0    33.0   98.0
# ...          ...       ...    ...  ...   ...      ...   ...     ...    ...
# 7725412    21806  20190630  100.0  0.0  95.0  24987.0  99.0    20.0   99.0
# 7725413    21811  20190630  100.0  0.0  93.0  31438.0  98.0  1014.0   98.0
# 7725414    21818  20190630  100.0  0.0  93.0  31443.0  98.0  1057.0   98.0
# 7725406    21658  20190630  100.0  0.0  95.0  23549.0  99.0    28.0   99.0
# 7754102     9989  20190630  100.0  0.0  95.0  24422.0  99.0    11.0   99.0
#
#          r_177  n_180    r_180  n_181  r_181  n_182  r_182  n_183  r_183  \
# 0         20.0  100.0  15238.0  100.0    0.0  100.0    0.0  100.0    0.0
# 29067    702.0  100.0  15301.0  100.0    0.0  100.0    0.0  100.0    0.0
# 29068    711.0  100.0  15310.0  100.0    0.0  100.0    0.0  100.0    0.0
# 29069    218.0  100.0  15292.0  100.0    0.0  100.0    0.0  100.0    0.0
# 29070    394.0  100.0  15341.0  100.0    0.0  100.0    0.0  100.0    0.0
# ...        ...    ...      ...    ...    ...    ...    ...    ...    ...
# 7725412  285.0  100.0  15310.0  100.0    0.0  100.0    0.0  100.0    0.0
# 7725413  592.0  100.0  15215.0  100.0    0.0  100.0    0.0  100.0    0.0
# 7725414  602.0  100.0  15284.0  100.0    0.0  100.0    0.0  100.0    0.0
# 7725406   68.0  100.0  15334.0  100.0    0.0  100.0    0.0  100.0    0.0
# 7754102  223.0  100.0  15289.0  100.0    0.0  100.0    0.0  100.0    0.0
#
#          n_187  r_187  n_190  r_190  n_195  r_195  n_199  r_199  n_241  \
# 0        100.0    0.0   71.0   29.0  200.0    0.0  100.0    0.0   99.0
# 29067    100.0    0.0   74.0   26.0  200.0    0.0  100.0    0.0   99.0
# 29068    100.0    0.0   68.0   32.0  200.0    0.0  100.0    0.0   99.0
# 29069    100.0    0.0   71.0   29.0  200.0    0.0  100.0    0.0   99.0
# 29070    100.0    0.0   72.0   28.0  200.0    0.0  100.0    0.0   99.0
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7725412  100.0    0.0   71.0   29.0  200.0    0.0  100.0    0.0   99.0
# 7725413  100.0    0.0   72.0   28.0  200.0    0.0  100.0    0.0   99.0
# 7725414  100.0    0.0   72.0   28.0  200.0    0.0  100.0    0.0   99.0
# 7725406  100.0    0.0   67.0   33.0  200.0    0.0  100.0    0.0   99.0
# 7754102  100.0    0.0   69.0   31.0  200.0    0.0  100.0    0.0   99.0
#
#                 r_241  n_242         r_242  r_244  label
# 0        6.916669e+10   99.0  4.377350e+09    0.0      0
# 29067    1.013831e+12   99.0  6.677894e+11    0.0      0
# 29068    2.286572e+12   99.0  4.380341e+11    0.0      0
# 29069    6.670700e+11   99.0  4.956816e+11    0.0      0
# 29070    4.731031e+11   99.0  1.697450e+10    0.0      0
# ...               ...    ...           ...    ...    ...
# 7725412  7.368685e+11   99.0  1.350921e+12    0.0      0
# 7725413  1.381409e+12   99.0  4.058834e+11    0.0      0
# 7725414  1.403214e+12   99.0  4.113683e+11    0.0      0
# 7725406  2.474254e+11   99.0  1.035013e+12    0.0      0
# 7754102  3.281347e+11   99.0  4.228293e+11    0.0      0
#
# [7754103 rows x 32 columns]

# %% [markdown]
# null값 지우고 하나의 데이터로만 이루어진 열을 제거한 데이터 프레임 shape과 columns확인

# %%
data.shape
# Out:
# (7754103, 32)

# %%
column = data.columns
column
# Out:
# Index(['disk_id', 'ds', 'n_5', 'r_5', 'n_9', 'r_9', 'n_12', 'r_12', 'n_177',
#        'r_177', 'n_180', 'r_180', 'n_181', 'r_181', 'n_182', 'r_182', 'n_183',
#        'r_183', 'n_187', 'r_187', 'n_190', 'r_190', 'n_195', 'r_195', 'n_199',
#        'r_199', 'n_241', 'r_241', 'n_242', 'r_242', 'r_244', 'label'],
#       dtype='object')

# %%
unique_disk_ids = data['disk_id'].nunique()
print("disk_id의 고유 개수:", unique_disk_ids)
# Out:
# disk_id의 고유 개수: 46298

# %% [markdown]
# fail이 일어난 행들 확인

# %%
data[data['label']==1]
# Out:
#          disk_id        ds    n_5     r_5   n_9      r_9  n_12   r_12  n_177  \
# 613835     23158  20190115  100.0     0.0  96.0  18828.0  99.0   35.0   99.0
# 605834     22793  20190115  100.0     0.0  94.0  29027.0  99.0   31.0   98.0
# 881437     33166  20190121  100.0     0.0  95.0  21140.0  99.0   46.0   99.0
# 948303     33132  20190122   95.0   708.0  96.0  20093.0  99.0   31.0   95.0
# 1030752    24640  20190124  100.0     0.0  96.0  19899.0  99.0   36.0   98.0
# 1227806    11241  20190129   93.0  1021.0  96.0  19211.0  99.0   22.0   99.0
# 1657944    21146  20190208  100.0     0.0  94.0  30234.0  99.0   28.0   98.0
# 1851928    25545  20190212  100.0     0.0  95.0  22523.0  99.0  267.0   99.0
# 2225372     1042  20190221   99.0     1.0  95.0  21093.0  99.0   27.0   99.0
# 2568092    33133  20190301  100.0     0.0  99.0     66.0  99.0    3.0  100.0
# 2754029    32791  20190306   80.0  2964.0  95.0  24486.0  99.0   19.0   98.0
# 2813616     3639  20190307   88.0  1731.0  95.0  24530.0  99.0   16.0   98.0
# 2856301    18527  20190308  100.0     0.0  95.0  21164.0  99.0   19.0   98.0
# 2921117    10351  20190309  100.0     0.0  95.0  21365.0  99.0   48.0   99.0
# 2979238    48773  20190311   99.0     2.0  95.0  24609.0  99.0   21.0   98.0
# 3565321     8869  20190324  100.0     0.0  96.0  19220.0  99.0   65.0   99.0
# 3731261    32909  20190328  100.0     0.0  95.0  20985.0  99.0   28.0   98.0
# 3884025     3489  20190331  100.0     0.0  93.0  30684.0  99.0   17.0   98.0
# 4039330    12078  20190404  100.0     0.0  95.0  22812.0  99.0   34.0   98.0
# 4059825    33839  20190405  100.0     0.0  99.0   4415.0  99.0   13.0   99.0
# 4338997    18217  20190411  100.0     0.0  93.0  31740.0  99.0   32.0   98.0
# 4365440    38850  20190412   99.0     2.0  95.0  22322.0  99.0   22.0   98.0
# 4471133    40866  20190414   87.0  1913.0  95.0  22350.0  99.0   25.0   99.0
# 4557908    41994  20190416  100.0     0.0  95.0  21001.0  99.0   25.0   99.0
# 4557909    41995  20190416  100.0     0.0  95.0  21001.0  99.0   25.0   99.0
# 4550222    41987  20190416  100.0     0.0  95.0  21001.0  99.0   23.0   99.0
# 4565812    41989  20190416  100.0     0.0  95.0  21002.0  99.0   25.0   99.0
# 4565813    41992  20190416  100.0     0.0  95.0  21002.0  99.0   25.0   99.0
# 4567747    41984  20190416  100.0     0.0  95.0  21001.0  99.0   23.0   99.0
# 4564783    18718  20190416  100.0     0.0  95.0  20944.0  99.0   34.0   99.0
# 4534910    41986  20190416  100.0     0.0  95.0  21001.0  99.0   25.0   99.0
# 4536786    41988  20190416  100.0     0.0  95.0  21001.0  99.0   25.0   99.0
# 4529179    41993  20190416  100.0     0.0  95.0  21001.0  99.0   23.0   99.0
# 4532969    41990  20190416  100.0     0.0  95.0  21001.0  99.0   23.0   99.0
# 4531023    41985  20190416  100.0     0.0  95.0  21001.0  99.0   25.0   99.0
# 5117122    40191  20190429   97.0   365.0  95.0  23006.0  99.0   56.0   98.0
# 5613605    47518  20190511   99.0    86.0  95.0  23896.0  99.0   27.0   99.0
# 5655446    30336  20190512   80.0  2952.0  95.0  24143.0  99.0   16.0   99.0
# 5749065    23801  20190514  100.0     0.0  95.0  21684.0  99.0   26.0   99.0
# 5726364     5426  20190514  100.0     0.0  95.0  23784.0  99.0   31.0   99.0
# 5733158    23806  20190514  100.0     0.0  95.0  21684.0  99.0   26.0   99.0
# 5827066     6174  20190516  100.0     0.0  93.0  31185.0  99.0   19.0   98.0
# 6058449    48237  20190521  100.0     0.0  94.0  27820.0  99.0   41.0   99.0
# 6140142    44805  20190523  100.0     0.0  99.0     19.0  99.0    7.0  100.0
# 6282447     1508  20190527   99.0     5.0  94.0  25373.0  99.0   39.0   98.0
# 6407164    27327  20190529   95.0   667.0  95.0  23423.0  99.0   22.0   98.0
# 7039782    46539  20190614  100.0     0.0  95.0  25044.0  99.0   12.0   99.0
# 7314532    44686  20190620  100.0     0.0  93.0  33435.0  99.0   28.0   98.0
# 7439515    26428  20190623   99.0     1.0  95.0  24834.0  99.0   12.0   99.0
#
#           r_177  n_180    r_180  n_181  r_181  n_182  r_182  n_183   r_183  \
# 613835     26.0  100.0  15307.0  100.0    0.0  100.0    0.0  100.0     0.0
# 605834    469.0  100.0  15244.0  100.0    0.0  100.0    0.0  100.0     0.0
# 881437    300.0  100.0  15348.0  100.0    0.0  100.0    0.0  100.0     0.0
# 948303   1958.0   95.0  14590.0  100.0    0.0  100.0    0.0   95.0   708.0
# 1030752   669.0  100.0  15327.0  100.0    0.0  100.0    0.0  100.0     0.0
# 1227806     4.0   93.0  14309.0  100.0    0.0  100.0    0.0   93.0  1021.0
# 1657944   550.0  100.0  15250.0  100.0    0.0  100.0    0.0  100.0     0.0
# 1851928    58.0  100.0  15298.0  100.0    0.0  100.0    0.0  100.0     0.0
# 2225372   200.0   99.0  15307.0  100.0    0.0  100.0    0.0   99.0     1.0
# 2568092     0.0  100.0  15284.0  100.0    0.0  100.0    0.0  100.0     0.0
# 2754029   440.0   80.0  12316.0  100.0    0.0  100.0    0.0   80.0  2964.0
# 2813616   425.0   88.0  13581.0  100.0    0.0  100.0    0.0   88.0  1731.0
# 2856301   437.0  100.0  15296.0  100.0    0.0  100.0    0.0  100.0     0.0
# 2921117   292.0  100.0  15275.0  100.0    0.0  100.0    0.0  100.0     0.0
# 2979238   675.0   99.0  15289.0  100.0    0.0  100.0    0.0   99.0     2.0
# 3565321   351.0  100.0  15324.0  100.0    0.0  100.0    0.0  100.0     0.0
# 3731261   455.0  100.0  15325.0  100.0    0.0  100.0    0.0  100.0     0.0
# 3884025   615.0  100.0  15290.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4039330   418.0  100.0  15322.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4059825     7.0  100.0  15323.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4338997   575.0  100.0  15181.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4365440   661.0   99.0  15246.0  100.0    0.0  100.0    0.0   99.0     2.0
# 4471133   102.0   87.0  13435.0  100.0    0.0  100.0    0.0   87.0  1913.0
# 4557908    46.0  100.0  15306.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4557909    49.0  100.0  15341.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4550222    47.0  100.0  15332.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4565812    46.0  100.0  15333.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4565813    47.0  100.0  15264.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4567747    48.0  100.0  15318.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4564783    48.0  100.0  15326.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4534910    47.0  100.0  15303.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4536786   256.0  100.0  15315.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4529179    47.0  100.0  15367.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4532969    51.0  100.0  15318.0  100.0    0.0  100.0    0.0  100.0     0.0
# 4531023    48.0  100.0  15317.0  100.0    0.0  100.0    0.0  100.0     0.0
# 5117122   721.0   97.0  14981.0  100.0    0.0  100.0    0.0   97.0   365.0
# 5613605   258.0   99.0  15258.0  100.0    0.0  100.0    0.0   99.0    86.0
# 5655446   349.0   80.0  12384.0  100.0    0.0  100.0    0.0   80.0  2952.0
# 5749065     8.0  100.0  15251.0  100.0    0.0  100.0    0.0  100.0     0.0
# 5726364   282.0  100.0  15330.0  100.0    0.0  100.0    0.0  100.0     0.0
# 5733158     8.0  100.0  15328.0  100.0    0.0  100.0    0.0  100.0     0.0
# 5827066   686.0  100.0  15250.0  100.0    0.0  100.0    0.0  100.0     0.0
# 6058449   332.0  100.0  15294.0  100.0    0.0  100.0    0.0  100.0     0.0
# 6140142     0.0  100.0  15371.0  100.0    0.0  100.0    0.0  100.0     0.0
# 6282447   602.0   99.0  15297.0  100.0    0.0  100.0    0.0   99.0     5.0
# 6407164   713.0   95.0  14668.0   95.0  666.0  100.0    0.0   95.0   667.0
# 7039782   318.0  100.0  15330.0  100.0    0.0  100.0    0.0  100.0     0.0
# 7314532   622.0  100.0  15237.0  100.0    0.0  100.0    0.0  100.0     0.0
# 7439515   339.0   99.0  15342.0  100.0    0.0  100.0    0.0   99.0     1.0
#
#          n_187    r_187  n_190  r_190  n_195    r_195  n_199     r_199  n_241  \
# 613835   100.0      0.0   68.0   32.0  200.0      0.0  100.0       0.0   99.0
# 605834   100.0      0.0   72.0   28.0  200.0      0.0   99.0       1.0   99.0
# 881437   100.0      0.0   71.0   29.0  200.0      0.0  100.0       0.0   99.0
# 948303    99.0     18.0   71.0   29.0  199.0     18.0  100.0       0.0   98.0
# 1030752  100.0      0.0   71.0   29.0  200.0      0.0  100.0       0.0   99.0
# 1227806   99.0      7.0   72.0   28.0  199.0      7.0  100.0       0.0   99.0
# 1657944  100.0      0.0   73.0   27.0  200.0      0.0   99.0       1.0   99.0
# 1851928  100.0      0.0   74.0   26.0  200.0      0.0  100.0       0.0   99.0
# 2225372   99.0      1.0   74.0   26.0  199.0      1.0  100.0       0.0   99.0
# 2568092  100.0      0.0   72.0   28.0  200.0      0.0  100.0       0.0   99.0
# 2754029   93.0  64822.0   72.0   28.0    1.0  64822.0  100.0       0.0   99.0
# 2813616   99.0     11.0   69.0   31.0  199.0     11.0  100.0       0.0   99.0
# 2856301  100.0      0.0   69.0   31.0  200.0      0.0  100.0       0.0   99.0
# 2921117  100.0      0.0   72.0   28.0  200.0      0.0   99.0     431.0   99.0
# 2979238  100.0      0.0   72.0   28.0  200.0      0.0  100.0       0.0   99.0
# 3565321  100.0      0.0   71.0   29.0  200.0      0.0   99.0     149.0   99.0
# 3731261  100.0      0.0   70.0   30.0  200.0      0.0   99.0     416.0   99.0
# 3884025  100.0      0.0   73.0   27.0  200.0      0.0   99.0       3.0   99.0
# 4039330  100.0      0.0   73.0   27.0  200.0      0.0  100.0       0.0   99.0
# 4059825   99.0      1.0   72.0   28.0  199.0      1.0   99.0      56.0   99.0
# 4338997  100.0      0.0   73.0   27.0  200.0      0.0   99.0     194.0   99.0
# 4365440  100.0      0.0   67.0   33.0  200.0      0.0  100.0       0.0   99.0
# 4471133   99.0    310.0   70.0   30.0  199.0    310.0  100.0       0.0   99.0
# 4557908  100.0      0.0   72.0   28.0  200.0      0.0  100.0       0.0   99.0
# 4557909  100.0      0.0   70.0   30.0  200.0      0.0  100.0       0.0   99.0
# 4550222  100.0      0.0   71.0   29.0  200.0      0.0  100.0       0.0   99.0
# 4565812  100.0      0.0   72.0   28.0  200.0      0.0  100.0       0.0   99.0
# 4565813  100.0      0.0   72.0   28.0  200.0      0.0  100.0       0.0   99.0
# 4567747  100.0      0.0   69.0   31.0  200.0      0.0  100.0       0.0   99.0
# 4564783  100.0      0.0   72.0   28.0  200.0      0.0  100.0       0.0   99.0
# 4534910  100.0      0.0   71.0   29.0  200.0      0.0  100.0       0.0   99.0
# 4536786  100.0      0.0   72.0   28.0  200.0      0.0  100.0       0.0   99.0
# 4529179  100.0      0.0   71.0   29.0  200.0      0.0  100.0       0.0   99.0
# 4532969  100.0      0.0   71.0   29.0  200.0      0.0  100.0       0.0   99.0
# 4531023  100.0      0.0   72.0   28.0  200.0      0.0  100.0       0.0   99.0
# 5117122   99.0      6.0   68.0   32.0  199.0      6.0  100.0       0.0   99.0
# 5613605   99.0     56.0   72.0   28.0  199.0     56.0  100.0       0.0   99.0
# 5655446   99.0     22.0   70.0   30.0  199.0     22.0  100.0       0.0   99.0
# 5749065  100.0      0.0   69.0   31.0  200.0      0.0  100.0       0.0   99.0
# 5726364  100.0      0.0   71.0   29.0  200.0      0.0  100.0       0.0   99.0
# 5733158  100.0      0.0   70.0   30.0  200.0      0.0  100.0       0.0   99.0
# 5827066  100.0      0.0   76.0   24.0  200.0      0.0   99.0       2.0   99.0
# 6058449  100.0      0.0   68.0   32.0  200.0      0.0    1.0  279173.0   99.0
# 6140142  100.0      0.0   71.0   29.0  200.0      0.0  100.0       0.0  100.0
# 6282447  100.0      0.0   67.0   33.0  200.0      0.0  100.0       0.0   99.0
# 6407164   99.0     37.0   69.0   31.0  199.0     37.0  100.0       0.0   99.0
# 7039782  100.0      0.0   67.0   33.0  200.0      0.0  100.0       0.0   99.0
# 7314532  100.0      0.0   73.0   27.0  200.0      0.0   99.0       1.0   99.0
# 7439515  100.0      0.0   73.0   27.0  200.0      0.0  100.0       0.0   99.0
#
#                 r_241  n_242         r_242  r_244  label
# 613835   5.850832e+10   99.0  3.090345e+10    0.0      1
# 605834   8.978095e+11   99.0  3.202639e+11    0.0      1
# 881437   4.063554e+11   99.0  6.291985e+09    0.0      1
# 948303   4.615791e+12   99.0  1.608638e+11    0.0      1
# 1030752  8.253349e+11   99.0  7.021858e+10    0.0      1
# 1227806  1.479124e+10   99.0  7.509899e+08    0.0      1
# 1657944  1.144791e+12   99.0  4.264358e+11    0.0      1
# 1851928  1.421696e+11   99.0  9.278635e+09    0.0      1
# 2225372  5.141455e+11   99.0  5.308122e+11    0.0      1
# 2568092  3.139740e+05   99.0  1.201100e+04    0.0      1
# 2754029  4.831223e+11   99.0  6.378199e+11    0.0      1
# 2813616  1.000042e+12   99.0  9.190172e+10    0.0      1
# 2856301  6.647938e+11   99.0  5.122248e+11    0.0      1
# 2921117  4.200762e+11   99.0  5.640154e+10    0.0      1
# 2979238  1.161920e+12   99.0  6.630394e+11    0.0      1
# 3565321  4.177199e+11   99.0  2.179738e+10    0.0      1
# 3731261  8.827575e+11   99.0  5.533557e+11    0.0      1
# 3884025  1.191281e+12   99.0  1.375521e+12    0.0      1
# 4039330  4.477665e+11   99.0  9.335185e+09    0.0      1
# 4059825  1.523629e+10   99.0  1.637540e+08    0.0      1
# 4338997  1.135837e+12   99.0  3.741844e+11    0.0      1
# 4365440  8.425246e+11   99.0  1.997352e+11    0.0      1
# 4471133  3.318411e+11   99.0  1.986768e+11    0.0      1
# 4557908  1.295565e+11   99.0  1.282030e+10    0.0      1
# 4557909  1.309459e+11   99.0  1.227880e+10    0.0      1
# 4550222  1.299188e+11   99.0  1.203084e+10    0.0      1
# 4565812  1.313240e+11   99.0  1.169805e+10    0.0      1
# 4565813  1.308302e+11   99.0  1.377038e+10    0.0      1
# 4567747  1.293461e+11   99.0  1.242363e+10    0.0      1
# 4564783  1.361009e+11   99.0  1.477416e+10    0.0      1
# 4534910  1.308863e+11   99.0  1.210357e+10    0.0      1
# 4536786  9.019227e+11   99.0  5.388997e+09    0.0      1
# 4529179  1.311799e+11   99.0  1.153290e+10    0.0      1
# 4532969  1.381698e+11   99.0  1.247068e+10    0.0      1
# 4531023  1.306296e+11   99.0  1.216263e+10    0.0      1
# 5117122  1.544462e+12   99.0  8.872846e+10    0.0      1
# 5613605  7.374434e+11   99.0  5.797346e+11    0.0      1
# 5655446  8.996567e+11   99.0  5.886770e+11    0.0      1
# 5749065  1.860662e+10   99.0  1.134124e+10    0.0      1
# 5726364  3.500105e+11   99.0  1.570979e+10    0.0      1
# 5733158  1.838099e+10   99.0  1.132383e+10    0.0      1
# 5827066  1.372843e+12   99.0  9.679964e+11    0.0      1
# 6058449  9.072698e+11   99.0  4.071602e+11    0.0      1
# 6140142  0.000000e+00   99.0  8.810000e+03    0.0      1
# 6282447  6.279719e+11   99.0  8.600651e+09    0.0      1
# 6407164  8.418024e+11   99.0  6.413192e+11    0.0      1
# 7039782  7.917610e+11   99.0  6.868357e+11    0.0      1
# 7314532  1.298766e+12   99.0  9.783280e+11    0.0      1
# 7439515  8.342562e+11   99.0  7.213156e+11    0.0      1

# %% [markdown]
# # 결측치 확인

# %% [markdown]
# 전체가 null인 컬럼과 단일값으로 이루어진 컬럼을 제거한 data에서 이제 null값을 알아보겠다.

# %%
null_counts = data.isnull().sum()
null_counts
# Out:
# disk_id      0
# ds           0
# n_5        474
# r_5        474
# n_9        475
# r_9        475
# n_12       472
# r_12       472
# n_177      477
# r_177      477
# n_180      488
# r_180      488
# n_181      506
# r_181      506
# n_182      510
# r_182      510
# n_183      541
# r_183      541
# n_187      507
# r_187      507
# n_190      505
# r_190      505
# n_195      508
# r_195      508
# n_199      499
# r_199      499
# n_241      493
# r_241      493
# n_242      485
# r_242      485
# r_244      499
# label        0
# dtype: int64

# %% [markdown]
# ?? 몇개의 feature에서는 180개 정도의 결측치가 있고 몇개의 feature에서는 1299850정도의 결측치가 있다.</br>
# 여기에서 disk_id별로 날짜를 다시 sort해서 그림으로 보자

# %%
sorted_data = data.sort_values(by=['disk_id', 'ds'])
# 결과 출력
sorted_data
# Out:
#          disk_id        ds    n_5  r_5   n_9      r_9  n_12  r_12  n_177  \
# 4007           0  20190101  100.0  0.0  95.0  20980.0  99.0  12.0   99.0
# 53585          0  20190102  100.0  0.0  95.0  21004.0  99.0  12.0   99.0
# 120183         0  20190103  100.0  0.0  95.0  21028.0  99.0  12.0   99.0
# 147852         0  20190104  100.0  0.0  95.0  21052.0  99.0  12.0   99.0
# 177451         0  20190105  100.0  0.0  95.0  21076.0  99.0  12.0   99.0
# ...          ...       ...    ...  ...   ...      ...   ...   ...    ...
# 7542960    49137  20190626  100.0  0.0  95.0  24449.0  99.0  35.0   99.0
# 7597590    49137  20190627  100.0  0.0  95.0  24473.0  99.0  35.0   99.0
# 7667196    49137  20190628  100.0  0.0  95.0  24497.0  99.0  35.0   99.0
# 7685103    49137  20190629  100.0  0.0  95.0  24521.0  99.0  35.0   99.0
# 7726642    49137  20190630  100.0  0.0  95.0  24545.0  99.0  35.0   99.0
#
#          r_177  n_180    r_180  n_181  r_181  n_182  r_182  n_183  r_183  \
# 4007     194.0  100.0  15303.0  100.0    0.0  100.0    0.0  100.0    0.0
# 53585    194.0  100.0  15303.0  100.0    0.0  100.0    0.0  100.0    0.0
# 120183   195.0  100.0  15303.0  100.0    0.0  100.0    0.0  100.0    0.0
# 147852   195.0  100.0  15303.0  100.0    0.0  100.0    0.0  100.0    0.0
# 177451   195.0  100.0  15303.0  100.0    0.0  100.0    0.0  100.0    0.0
# ...        ...    ...      ...    ...    ...    ...    ...    ...    ...
# 7542960   50.0  100.0  15361.0  100.0    0.0  100.0    0.0  100.0    0.0
# 7597590   50.0  100.0  15361.0  100.0    0.0  100.0    0.0  100.0    0.0
# 7667196   50.0  100.0  15361.0  100.0    0.0  100.0    0.0  100.0    0.0
# 7685103   50.0  100.0  15361.0  100.0    0.0  100.0    0.0  100.0    0.0
# 7726642   50.0  100.0  15361.0  100.0    0.0  100.0    0.0  100.0    0.0
#
#          n_187  r_187  n_190  r_190  n_195  r_195  n_199  r_199  n_241  \
# 4007     100.0    0.0   70.0   30.0  200.0    0.0  100.0    0.0   99.0
# 53585    100.0    0.0   70.0   30.0  200.0    0.0  100.0    0.0   99.0
# 120183   100.0    0.0   70.0   30.0  200.0    0.0  100.0    0.0   99.0
# 147852   100.0    0.0   70.0   30.0  200.0    0.0  100.0    0.0   99.0
# 177451   100.0    0.0   70.0   30.0  200.0    0.0  100.0    0.0   99.0
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7542960  100.0    0.0   65.0   35.0  200.0    0.0  100.0    0.0   99.0
# 7597590  100.0    0.0   65.0   35.0  200.0    0.0  100.0    0.0   99.0
# 7667196  100.0    0.0   65.0   35.0  200.0    0.0  100.0    0.0   99.0
# 7685103  100.0    0.0   65.0   35.0  200.0    0.0  100.0    0.0   99.0
# 7726642  100.0    0.0   65.0   35.0  200.0    0.0  100.0    0.0   99.0
#
#                 r_241  n_242         r_242  r_244  label
# 4007     5.681933e+11   99.0  4.796424e+11    0.0      0
# 53585    5.692730e+11   99.0  4.806083e+11    0.0      0
# 120183   5.704268e+11   99.0  4.816604e+11    0.0      0
# 147852   5.713944e+11   99.0  4.826586e+11    0.0      0
# 177451   5.723356e+11   99.0  4.836563e+11    0.0      0
# ...               ...    ...           ...    ...    ...
# 7542960  1.363780e+11   99.0  7.976450e+09    0.0      0
# 7597590  1.365014e+11   99.0  7.976612e+09    0.0      0
# 7667196  1.366111e+11   99.0  7.976729e+09    0.0      0
# 7685103  1.367149e+11   99.0  7.976843e+09    0.0      0
# 7726642  1.368233e+11   99.0  7.976940e+09    0.0      0
#
# [7754103 rows x 32 columns]

# %%
import missingno as msno
msno.matrix(sorted_data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 그림으로 보니까 이 null값들은 동시에 같이 가지는거같다. 그래서 동시에 이 feature에 대해서 null값을 가지는지 알아보자. 일단 지금은 1299850 정도의 결측치가 있는 컬럼에 적용시켜보자

# %%
# 원하는 컬럼 리스트
desired_columns = ['n_5', 'r_5', 'n_9', 'r_9', 'n_12', 'r_12', 'n_177', 'r_177', 'n_180', 'r_180', 'n_181', 'r_181', 'n_182', 'r_182', 'n_183','r_183', 'n_187', 'r_187', 'n_190', 'r_190', 'n_195', 'r_195', 'n_199', 'r_199', 'n_241', 'r_241', 'n_242', 'r_242', 'r_244']

# 동시에 null 값을 가지는 행 개수 계산
null_counts = data[desired_columns].isnull().all(axis=1).sum()

# 결과 출력
print("동시에 null 값을 가지는 행 개수:", null_counts)
# Out:
# 동시에 null 값을 가지는 행 개수: 55

# %% [markdown]
# 동시에 null값을 가지는 행이 1299740개나 있다. 즉 특정 feature들은 없으면 다같이 없다고 볼수 있다. </br>
# 이런 결측치를 가진 행의 disk_id가 어떠한지 알아보자.</br>
# 하나의 disk_id에서 전체가 다 기록이 안되는지 아니면 특정 시점부터 기록이 되는지 아니면 잘 기록되는데 몇몇개만 같이 빠져있는지 확인해보자

# %% [markdown]
# 일단 동시에 null을 가지는 행들을 따로 가져와서 null_rows라는 변수에 저장하자

# %%
# 원하는 컬럼 리스트
desired_columns = ['n_5', 'r_5', 'n_9', 'r_9', 'n_12', 'r_12', 'n_177','r_177', 'n_180', 'r_180', 'n_181', 'r_181', 'n_182', 'r_182', 'n_183', 'r_183', 'n_187', 'r_187', 'n_190', 'r_190', 'n_195', 'r_195', 'n_199', 'r_199', 'n_241', 'r_241', 'n_242', 'r_242', 'r_244',]

# 동시에 null 값을 가지는 행 선택
null_rows = data[data[desired_columns].isnull().all(axis=1)]

# 결과 출력
null_rows
# Out:
#          disk_id        ds  n_5  r_5  n_9  r_9  n_12  r_12  n_177  r_177  \
# 31139      36277  20190101  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
# 95345      20318  20190103  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
# 92449      43100  20190103  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
# 160992     37748  20190104  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
# 225981      3838  20190106  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
# ...          ...       ...  ...  ...  ...  ...   ...   ...    ...    ...
# 7036459    14700  20190614  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
# 7213396    27258  20190618  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
# 7230816    27263  20190618  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
# 7207411    25345  20190618  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
# 7205701     3158  20190618  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN
#
#          n_180  r_180  n_181  r_181  n_182  r_182  n_183  r_183  n_187  r_187  \
# 31139      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 95345      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 92449      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 160992     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 225981     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7036459    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7213396    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7230816    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7207411    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7205701    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#          n_190  r_190  n_195  r_195  n_199  r_199  n_241  r_241  n_242  r_242  \
# 31139      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 95345      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 92449      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 160992     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 225981     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7036459    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7213396    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7230816    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7207411    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7205701    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#          r_244  label
# 31139      NaN      0
# 95345      NaN      0
# 92449      NaN      0
# 160992     NaN      0
# 225981     NaN      0
# ...        ...    ...
# 7036459    NaN      0
# 7213396    NaN      0
# 7230816    NaN      0
# 7207411    NaN      0
# 7205701    NaN      0
#
# [55 rows x 32 columns]

# %% [markdown]
# 그리고 disk_id 별로 이런 결측치 행이 몇개가 있는지 value_counts()로 알아보자

# %%
# 중복되는 disk_id 값들과 중복 횟수 확인
duplicate_counts = null_rows['disk_id'].value_counts()

# 중복되는 disk_id 값과 중복 횟수 출력
print("중복되는 disk_id 값들과 중복 횟수:")
duplicate_counts
# Out:
# 중복되는 disk_id 값들과 중복 횟수:
# disk_id
# 36277    1
# 13880    1
# 44203    1
# 17869    1
# 13181    1
#         ..
# 27942    1
# 12276    1
# 47528    1
# 16654    1
# 3158     1
# Name: count, Length: 55, dtype: int64

# %%
# 중복되는 disk_id 값들과 중복 횟수 확인
duplicate_counts = null_rows['disk_id'].value_counts()

# 빈도가 180인 값들 선택
values_with_frequency_180 = duplicate_counts[duplicate_counts == 180]

# 빈도가 180인 값들의 개수
count_values_with_frequency_180 = len(values_with_frequency_180)

# 결과 출력
print("빈도가 180인 값들의 개수:", count_values_with_frequency_180)
# Out:
# 빈도가 180인 값들의 개수: 0

# %%
# 개수의 개수(count)를 계산
count_counts = duplicate_counts.value_counts()

# 막대 그래프 그리기
plt.bar(count_counts.index, count_counts.values)

# 그래프 제목과 라벨 설정
plt.title('Count Counts')
plt.xlabel('Count')
plt.ylabel('Frequency')

# 그래프 출력
plt.show()

# %%
for disk_id, count in duplicate_counts.items():
    print("disk_id:", disk_id, "- 중복 횟수:", count)
# Out:
# disk_id: 36277 - 중복 횟수: 1
# disk_id: 13880 - 중복 횟수: 1
# disk_id: 44203 - 중복 횟수: 1
# disk_id: 17869 - 중복 횟수: 1
# disk_id: 13181 - 중복 횟수: 1
# disk_id: 20205 - 중복 횟수: 1
# disk_id: 21205 - 중복 횟수: 1
# disk_id: 5584 - 중복 횟수: 1
# disk_id: 42150 - 중복 횟수: 1
# disk_id: 7072 - 중복 횟수: 1
# disk_id: 33588 - 중복 횟수: 1
# disk_id: 35089 - 중복 횟수: 1
# disk_id: 42714 - 중복 횟수: 1
# disk_id: 1596 - 중복 횟수: 1
# disk_id: 36911 - 중복 횟수: 1
# disk_id: 17597 - 중복 횟수: 1
# disk_id: 32305 - 중복 횟수: 1
# disk_id: 16313 - 중복 횟수: 1
# disk_id: 8625 - 중복 횟수: 1
# disk_id: 46028 - 중복 횟수: 1
# disk_id: 37563 - 중복 횟수: 1
# disk_id: 39939 - 중복 횟수: 1
# disk_id: 14700 - 중복 횟수: 1
# disk_id: 27258 - 중복 횟수: 1
# disk_id: 27263 - 중복 횟수: 1
# disk_id: 25345 - 중복 횟수: 1
# disk_id: 30782 - 중복 횟수: 1
# disk_id: 16661 - 중복 횟수: 1
# disk_id: 20318 - 중복 횟수: 1
# disk_id: 25900 - 중복 횟수: 1
# disk_id: 43100 - 중복 횟수: 1
# disk_id: 37748 - 중복 횟수: 1
# disk_id: 3838 - 중복 횟수: 1
# disk_id: 29157 - 중복 횟수: 1
# disk_id: 22437 - 중복 횟수: 1
# disk_id: 1858 - 중복 횟수: 1
# disk_id: 3027 - 중복 횟수: 1
# disk_id: 12211 - 중복 횟수: 1
# disk_id: 45201 - 중복 횟수: 1
# disk_id: 7750 - 중복 횟수: 1
# disk_id: 16809 - 중복 횟수: 1
# disk_id: 23143 - 중복 횟수: 1
# disk_id: 44788 - 중복 횟수: 1
# disk_id: 16642 - 중복 횟수: 1
# disk_id: 22761 - 중복 횟수: 1
# disk_id: 26930 - 중복 횟수: 1
# disk_id: 15347 - 중복 횟수: 1
# disk_id: 4612 - 중복 횟수: 1
# disk_id: 24975 - 중복 횟수: 1
# disk_id: 46736 - 중복 횟수: 1
# disk_id: 27942 - 중복 횟수: 1
# disk_id: 12276 - 중복 횟수: 1
# disk_id: 47528 - 중복 횟수: 1
# disk_id: 16654 - 중복 횟수: 1
# disk_id: 3158 - 중복 횟수: 1

# %% [markdown]
# 정리를 하자면 특정 컬럼에서 동시에 null값을 가지는 행들에서 6개월동안 그러한 측정값을 가지고 있는 disk_id는 2153개가 있고 <br>
# 그래프를 보면 6개월동안 180개가 아닌 더 적은 개수로도 관측이 되는것을 볼수 있다. <br>
# 여기서 우리는 두가지로 생각할수 있는데 모든 disk_id에서 한번 그렇게 관측이 되면 그렇게 되는데 특정시점부터 관측이 되서 그런것인가<br>
# 아니면 제대로 모든 feature가 관측이 되고 있는데 중간중간 갑자기 관측이 안되는 경우인가<br>
# 이 두가지를 생각하면서 코드를 만들어야한다.

# %%
data[data['disk_id']==10659]
# Out:
#          disk_id        ds           r_1   n_5  r_5      r_9  r_12  n_171  \
# 4019       10659  20190101  4.294967e+09  98.0  0.0  40517.0  44.0  100.0
# 45202      10659  20190102  4.294967e+09  98.0  0.0  40541.0  44.0  100.0
# 74436      10659  20190103  4.294967e+09  98.0  0.0  40565.0  44.0  100.0
# 109082     10659  20190104  4.294967e+09  98.0  0.0  40589.0  44.0  100.0
# 119353     10659  20190105  4.294967e+09  98.0  0.0  40612.0  44.0  100.0
# ...          ...       ...           ...   ...  ...      ...   ...    ...
# 4628869    10659  20190626  4.294967e+09  98.0  0.0  44727.0  44.0  100.0
# 4662718    10659  20190627  4.294967e+09  98.0  0.0  44751.0  44.0  100.0
# 4691885    10659  20190628  4.294967e+09  98.0  0.0  44775.0  44.0  100.0
# 4707279    10659  20190629  4.294967e+09  98.0  0.0  44799.0  44.0  100.0
# 4730255    10659  20190630  4.294967e+09  98.0  0.0  44823.0  44.0  100.0
#
#          r_171  n_172  r_172  n_173  r_174  n_180         r_180  n_184  r_184  \
# 4019       0.0  100.0    0.0   88.0   42.0  130.0  4.294967e+09  100.0    0.0
# 45202      0.0  100.0    0.0   88.0   42.0  130.0  4.294967e+09  100.0    0.0
# 74436      0.0  100.0    0.0   88.0   42.0  130.0  4.294967e+09  100.0    0.0
# 109082     0.0  100.0    0.0   88.0   42.0  130.0  4.294967e+09  100.0    0.0
# 119353     0.0  100.0    0.0   88.0   42.0  130.0  4.294967e+09  100.0    0.0
# ...        ...    ...    ...    ...    ...    ...           ...    ...    ...
# 4628869    0.0  100.0    0.0   80.0   42.0  130.0  4.294967e+09  100.0    0.0
# 4662718    0.0  100.0    0.0   80.0   42.0  130.0  4.294967e+09  100.0    0.0
# 4691885    0.0  100.0    0.0   80.0   42.0  130.0  4.294967e+09  100.0    0.0
# 4707279    0.0  100.0    0.0   80.0   42.0  130.0  4.294967e+09  100.0    0.0
# 4730255    0.0  100.0    0.0   80.0   42.0  130.0  4.294967e+09  100.0    0.0
#
#          r_187  r_188  n_190  r_190  r_194        r_195  n_196  r_196  r_197  \
# 4019       0.0    0.0   86.0   14.0   14.0  220097443.0  100.0    0.0    0.0
# 45202      0.0    0.0   86.0   14.0   14.0  220387271.0  100.0    0.0    0.0
# 74436      0.0    0.0   86.0   14.0   14.0  220643194.0  100.0    0.0    0.0
# 109082     0.0    0.0   86.0   14.0   14.0  220889626.0  100.0    0.0    0.0
# 119353     0.0    0.0   86.0   14.0   14.0  221133417.0  100.0    0.0    0.0
# ...        ...    ...    ...    ...    ...          ...    ...    ...    ...
# 4628869    0.0    0.0   85.0   15.0   15.0  375604789.0  100.0    0.0    0.0
# 4662718    0.0    0.0   85.0   15.0   15.0  376342191.0  100.0    0.0    0.0
# 4691885    0.0    0.0   86.0   14.0   14.0  377430462.0  100.0    0.0    0.0
# 4707279    0.0    0.0   86.0   14.0   14.0  378505546.0  100.0    0.0    0.0
# 4730255    0.0    0.0   86.0   14.0   14.0  379580344.0  100.0    0.0    0.0
#
#          r_198  r_199  n_175         r_175  label
# 4019       0.0    0.0  100.0  1.026602e+12      0
# 45202      0.0    0.0  100.0  1.026696e+12      0
# 74436      0.0    0.0  100.0  1.026790e+12      0
# 109082     0.0    0.0  100.0  1.026884e+12      0
# 119353     0.0    0.0  100.0  1.026977e+12      0
# ...        ...    ...    ...           ...    ...
# 4628869    0.0    0.0  100.0  1.134015e+12      0
# 4662718    0.0    0.0  100.0  1.134109e+12      0
# 4691885    0.0    0.0  100.0  1.134204e+12      0
# 4707279    0.0    0.0  100.0  1.134298e+12      0
# 4730255    0.0    0.0  100.0  1.134392e+12      0
#
# [180 rows x 31 columns]

# %% [markdown]
# 각각 개수에서 sample로 몇개 들고 왔을때는 중간부터 관측이 안되는것이 아니라 그냥 처음부터 관측은 다같이 안되는 것으로 보인다.<br>
# 즉 몇몇의 특성들은 다같이 처음부터 관측이 안 되는것으로 보인다.<br>
# 그런데 그런 행을 가진 disk_id가 하나일때 중간에 한번 안된것들로 보이는 값들도 있다.

# %% [markdown]
# # 여기서부터 코딩 해봐야해.....

# %% [markdown]
# 뭔가 지금 해야할것이 우리가 특정 샘플들을 가져와서 하나씩 했는데 확실히 그게 다 맞는건인지 확인하는 코드?를 짜봐야할거같고<br>
# 한개일때 실제로 한개로 이루어진 disk_id랑 중간에 하나 결측치로 되어있는 disk_id가 있는데 그것을 어떻게 할지를 생각해봐야한다<br>
# 지금은 실제로 machine learning 모델을 돌릴때 한개들 다 삭제하고 싶다....
# 그리고 결측치가 180개로 이루어진건 뭔지 함 보고 insight를 쌓아햐함 아래에 r_1에서 결측치를 확인하는 코드를 좀 끄적이긴 했는데 더 해야대...

# %%
# 원하는 컬럼 리스트
desired_columns = ['r_12', 'n_171', 'r_171', 'n_172', 'r_172', 'r_174', 'n_184', 'r_184', 'r_187', 'r_188', 'n_190', 'r_190', 'r_195', 'r_197', 'r_198', 'r_199']

# 하나 이상의 컬럼에 null 값을 가지지 않는 행 선택
non_null_rows = data[data[desired_columns].notnull().any(axis=1)]

# 결과 출력
non_null_rows
# Out:
#          disk_id        ds           r_1   n_5  r_5      r_9  r_12  n_171  \
# 19059       3614  20190101  4.294967e+09  96.0  0.0  44475.0  26.0  100.0
# 19058      36107  20190101  4.294967e+09  97.0  0.0  40372.0  37.0  100.0
# 19057      36104  20190101  4.294967e+09  98.0  0.0  40369.0  37.0  100.0
# 19056        361  20190101  3.276881e+09  95.0  2.0  46646.0  39.0  100.0
# 19055      36082  20190101  4.294967e+09  98.0  0.0  37598.0  40.0  100.0
# ...          ...       ...           ...   ...  ...      ...   ...    ...
# 4728268    17792  20190630  4.294967e+09  98.0  0.0  43118.0  31.0  100.0
# 4728267     1779  20190630  4.294967e+09  98.0  0.0  45020.0  29.0  100.0
# 4728264    17715  20190630  4.294967e+09  96.0  0.0  40284.0  52.0  100.0
# 4728273    17929  20190630  4.294967e+09  97.0  1.0  49490.0  47.0  100.0
# 4744314     9974  20190630  4.294967e+09  96.0  0.0  46623.0  44.0  100.0
#
#          r_171  n_172  r_172  n_173  r_174  n_180         r_180  n_184  r_184  \
# 19059      0.0  100.0    0.0   69.0   23.0  130.0  4.294967e+09  100.0    0.0
# 19058      0.0  100.0    0.0   90.0   35.0  130.0  4.294967e+09  100.0    0.0
# 19057      0.0  100.0    0.0   85.0   35.0  130.0  4.294967e+09  100.0    0.0
# 19056      1.0  100.0    0.0   75.0   36.0  130.0  4.054609e+09  100.0    0.0
# 19055      0.0  100.0    0.0   85.0   38.0  130.0  4.294967e+09  100.0    0.0
# ...        ...    ...    ...    ...    ...    ...           ...    ...    ...
# 4728268    0.0  100.0    0.0   96.0   29.0  130.0  4.294967e+09  100.0    0.0
# 4728267    0.0  100.0    0.0   93.0   27.0  130.0  4.294967e+09  100.0    0.0
# 4728264    0.0  100.0    0.0   98.0   50.0  130.0  4.294967e+09  100.0    0.0
# 4728273    0.0  100.0    0.0   60.0   44.0  130.0  4.294967e+09  100.0    0.0
# 4744314    0.0  100.0    0.0   82.0   41.0  130.0  4.294967e+09  100.0    0.0
#
#          r_187  r_188  n_190  r_190  r_194         r_195  n_196  r_196  r_197  \
# 19059      0.0    0.0   89.0   11.0   11.0  1.120414e+09  100.0    0.0    0.0
# 19058      0.0    0.0   84.0   16.0   16.0  8.552900e+05  100.0    0.0    0.0
# 19057      0.0    0.0   84.0   16.0   16.0  1.044777e+06  100.0    0.0    0.0
# 19056      0.0    0.0   84.0   16.0   16.0  1.091491e+06   99.0    2.0    0.0
# 19055      0.0    0.0   81.0   19.0   19.0  1.006528e+07  100.0    0.0    0.0
# ...        ...    ...    ...    ...    ...           ...    ...    ...    ...
# 4728268    0.0    0.0   86.0   14.0   14.0  1.018570e+05  100.0    0.0    0.0
# 4728267    0.0    0.0   85.0   15.0   15.0  1.886397e+07  100.0    0.0    0.0
# 4728264    0.0    0.0   86.0   14.0   14.0  8.232852e+06  100.0    0.0    0.0
# 4728273    0.0    0.0   86.0   14.0   14.0  4.142201e+08   99.0    1.0    0.0
# 4744314    0.0    0.0   86.0   14.0   14.0  3.944694e+08  100.0    0.0    0.0
#
#          r_198  r_199  n_175         r_175  label
# 19059      0.0    0.0  100.0  1.125649e+12      0
# 19058      0.0    0.0  100.0  1.014122e+12      0
# 19057      0.0    0.0  100.0  1.014122e+12      0
# 19056      0.0    0.0  100.0  1.181125e+12      0
# 19055      0.0    0.0  100.0  9.455094e+11      0
# ...        ...    ...    ...           ...    ...
# 4728268    0.0    0.0  100.0  1.099828e+12      0
# 4728267    0.0    0.0  100.0  1.143073e+12      0
# 4728264    0.0    0.0  100.0  1.018248e+12      0
# 4728273    0.0    0.0  100.0  1.241550e+12      0
# 4744314    0.0    0.0  100.0  1.164486e+12      0
#
# [3444575 rows x 31 columns]

# %%
# 원하는 컬럼 리스트
desired_columns = ['r_12', 'n_171', 'r_171', 'n_172', 'r_172', 'r_174', 'n_184', 'r_184', 'r_187', 'r_188', 'n_190', 'r_190', 'r_195', 'r_197', 'r_198', 'r_199']

# 하나 이상의 컬럼에 null 값을 가지지 않고, label이 1인 행 선택
filtered_rows = data[data[desired_columns].notnull().any(axis=1) & (data['label'] == 1)]

# 결과 출력
filtered_rows
# Out:
#          disk_id        ds           r_1   n_5    r_5      r_9  r_12  n_171  \
# 55936      23729  20190102  4.294967e+09  98.0    2.0  40175.0  28.0  100.0
# 55019       3401  20190102  4.294967e+09  98.0    0.0  40012.0  59.0  100.0
# 75070      30146  20190103  4.294967e+09  98.0    0.0  36922.0  30.0  100.0
# 70405      41793  20190103  4.294967e+09  98.0    0.0  36522.0  28.0  100.0
# 106266     37927  20190104  4.294967e+09  94.0  141.0  37481.0  30.0   99.0
# ...          ...       ...           ...   ...    ...      ...   ...    ...
# 4112479     4402  20190603  4.294967e+09  98.0    3.0  41148.0  34.0  100.0
# 4178901    34874  20190605  4.294967e+09  98.0    0.0  40585.0  28.0  100.0
# 4175174     1230  20190605  4.294967e+09  98.0    0.0  44244.0  27.0  100.0
# 4195779    38773  20190606  4.294967e+09  98.0    2.0  44298.0  37.0  100.0
# 4182969    31327  20190606  4.294967e+09  98.0    0.0  42078.0  44.0  100.0
#
#          r_171  n_172  r_172  n_173  r_174  n_180         r_180  n_184  r_184  \
# 55936      4.0  100.0    0.0    1.0   26.0  130.0  4.294967e+09  100.0    0.0
# 55019      0.0  100.0    0.0    1.0   57.0  130.0  4.294967e+09  100.0    0.0
# 75070      0.0  100.0    0.0    1.0   28.0  130.0  4.294967e+09  100.0    0.0
# 70405      0.0  100.0    0.0   83.0   26.0  130.0  4.294967e+09  100.0    0.0
# 106266    70.0  100.0    0.0    1.0   28.0  130.0  4.294967e+09  100.0    0.0
# ...        ...    ...    ...    ...    ...    ...           ...    ...    ...
# 4112479    1.0  100.0    1.0    1.0   32.0  130.0  4.294967e+09  100.0    0.0
# 4178901    0.0  100.0    0.0    1.0   26.0  130.0  4.294967e+09  100.0    0.0
# 4175174    0.0  100.0    0.0    1.0   25.0  130.0  4.294967e+09  100.0    0.0
# 4195779    2.0  100.0    0.0    1.0   35.0  130.0  4.294967e+09  100.0    0.0
# 4182969    0.0  100.0    0.0    1.0   42.0  130.0  4.294967e+09  100.0    0.0
#
#          r_187  r_188  n_190  r_190  r_194         r_195  n_196  r_196  r_197  \
# 55936      0.0    0.0   80.0   20.0   20.0  1.067805e+09   99.0    2.0    0.0
# 55019      0.0    0.0   84.0   16.0   16.0  2.260676e+09  100.0    0.0    0.0
# 75070      0.0    0.0   82.0   18.0   18.0  1.591232e+09  100.0    0.0    0.0
# 70405      0.0    0.0   86.0   14.0   14.0  2.791970e+08  100.0    0.0    0.0
# 106266     0.0    0.0   92.0    8.0    8.0  2.748596e+09   97.0  141.0    0.0
# ...        ...    ...    ...    ...    ...           ...    ...    ...    ...
# 4112479    0.0    0.0   85.0   15.0   15.0  4.670091e+08   99.0    3.0    0.0
# 4178901    0.0    0.0   85.0   15.0   15.0  1.579518e+09  100.0    0.0    0.0
# 4175174    0.0    3.0   81.0   19.0   19.0  2.581993e+09  100.0    0.0    0.0
# 4195779    0.0    0.0   84.0   16.0   16.0  1.970826e+09   99.0    2.0    0.0
# 4182969    0.0    0.0   83.0   17.0   17.0  3.873290e+09  100.0    0.0    0.0
#
#          r_198  r_199  n_175         r_175  label
# 55936      0.0    0.0  100.0  1.018337e+12      1
# 55019      0.0    0.0  100.0  1.005077e+12      1
# 75070      0.0    0.0  100.0  9.407059e+11      1
# 70405      0.0    0.0  100.0  9.280304e+11      1
# 106266     0.0    0.0  100.0  9.497040e+11      1
# ...        ...    ...    ...           ...    ...
# 4112479    0.0    0.0  100.0  1.039979e+12      1
# 4178901    0.0    0.0  100.0  1.035432e+12      1
# 4175174    0.0    0.0  100.0  1.125316e+12      1
# 4195779    0.0    0.0  100.0  1.121018e+12      1
# 4182969    0.0    0.0  100.0  1.057160e+12      1
#
# [229 rows x 31 columns]

# %%
rows_with_missing_r1 = data[data['r_1'].isnull()]
rows_with_missing_r1[:100]
# Out:
#          disk_id        ds  r_1   n_5  r_5      r_9  r_12  n_171  r_171  \
# 21853      42362  20190101  NaN   NaN  NaN      NaN  27.0  100.0    0.0
# 3107       23214  20190101  NaN   NaN  NaN      NaN   NaN    NaN    NaN
# 2446       42366  20190101  NaN   NaN  NaN      NaN   NaN    NaN    NaN
# 11578      42368  20190101  NaN   NaN  NaN      NaN   NaN    NaN    NaN
# 13169      11673  20190101  NaN  98.0  0.0  36225.0  37.0  100.0    0.0
# ...          ...       ...  ...   ...  ...      ...   ...    ...    ...
# 1691350    32995  20190302  NaN   NaN  NaN      NaN   NaN    NaN    NaN
# 1791141     9232  20190305  NaN   NaN  NaN      NaN   NaN    NaN    NaN
# 1797287    36062  20190306  NaN   NaN  NaN      NaN   NaN    NaN    NaN
# 1831616    18612  20190307  NaN  94.0  0.0  47455.0  30.0  100.0    0.0
# 1888735    22503  20190309  NaN   NaN  NaN      NaN   NaN    NaN    NaN
#
#          n_172  r_172  n_173  r_174  n_180         r_180  n_184  r_184  r_187  \
# 21853    100.0    0.0    NaN    NaN    NaN           NaN    NaN    NaN    NaN
# 3107       NaN    NaN    NaN    NaN  130.0  4.294967e+09  100.0    0.0    0.0
# 2446       NaN    NaN    NaN    NaN    NaN           NaN    NaN    NaN    NaN
# 11578      NaN    NaN    NaN    NaN    NaN           NaN    NaN    NaN    NaN
# 13169    100.0    0.0   95.0   35.0  130.0  4.294967e+09  100.0    0.0    0.0
# ...        ...    ...    ...    ...    ...           ...    ...    ...    ...
# 1691350    NaN    NaN    NaN    NaN    NaN           NaN    NaN    NaN    NaN
# 1791141    NaN    NaN    NaN   34.0  130.0  3.380104e+09  100.0    0.0    0.0
# 1797287    NaN    NaN    NaN    NaN  130.0  4.294967e+09  100.0    0.0    0.0
# 1831616  100.0    0.0   41.0   27.0  130.0  4.294967e+09  100.0    0.0    0.0
# 1888735    NaN    NaN    NaN    NaN    NaN           NaN    NaN    NaN    NaN
#
#          r_188  n_190  r_190  r_194         r_195  n_196  r_196  r_197  r_198  \
# 21853      NaN    NaN    NaN    NaN           NaN    NaN    NaN    NaN    NaN
# 3107       0.0   85.0   15.0   15.0  2.658806e+07  100.0    0.0    0.0    0.0
# 2446       0.0   86.0   14.0   14.0  3.122873e+09  100.0    0.0    0.0    0.0
# 11578      NaN    NaN    NaN    NaN  2.992188e+09  100.0    0.0    0.0    0.0
# 13169      0.0   85.0   15.0   15.0  5.976232e+06  100.0    0.0    0.0    0.0
# ...        ...    ...    ...    ...           ...    ...    ...    ...    ...
# 1691350    0.0   87.0   13.0   13.0  6.139713e+08  100.0    0.0    0.0    0.0
# 1791141    5.0   87.0   13.0   13.0  4.001040e+05  100.0    0.0    0.0    0.0
# 1797287    0.0   81.0   19.0   19.0  9.234537e+07  100.0    0.0    0.0    0.0
# 1831616    0.0   85.0   15.0   15.0  8.856299e+08  100.0    0.0    0.0    0.0
# 1888735    0.0   87.0   13.0   13.0  5.267280e+05  100.0    0.0    0.0    0.0
#
#          r_199  n_175         r_175  label
# 21853      NaN    NaN           NaN      0
# 3107       0.0  100.0  9.496752e+11      0
# 2446       0.0    NaN           NaN      0
# 11578      0.0    NaN           NaN      0
# 13169      0.0  100.0  9.154515e+11      0
# ...        ...    ...           ...    ...
# 1691350    0.0    NaN           NaN      0
# 1791141    0.0  100.0  9.878659e+11      0
# 1797287    0.0    NaN           NaN      0
# 1831616    0.0  100.0  1.198631e+12      0
# 1888735    0.0    NaN           NaN      0
#
# [100 rows x 31 columns]

# %% [markdown]
# # disk_id랑 feature별로 scatter plot을 그려서 데이터 추세 파악하기</br>
# 이때 날짜가 없는 행은 null값으로 채운다

# %%
disk_id = 1323
features = ['r_1', 'n_5', 'r_5', 'r_9', 'r_12', 'n_171', 'r_171',
       'n_172', 'r_172', 'n_173', 'r_174', 'n_180', 'r_180', 'n_184', 'r_184',
       'r_187', 'r_188', 'n_190', 'r_190', 'r_194', 'r_195', 'n_196', 'r_196',
       'r_197', 'r_198', 'r_199', 'n_175', 'r_175']

filtered_df = data[data['disk_id'] == disk_id]

if filtered_df.empty:
    print(f"No data available for disk_id {disk_id}.")
else:
    # 날짜(ds)를 datetime 형식으로 변환
    filtered_df['ds'] = pd.to_datetime(filtered_df['ds'], format='%Y%m%d')
    
    # 모든 날짜를 생성합니다.
    all_dates = pd.date_range(start=filtered_df['ds'].min(), end=filtered_df['ds'].max())
    
    # 모든 날짜를 포함하도록 filtered_df를 확장합니다.
    filtered_df = filtered_df.set_index('ds').reindex(all_dates).rename_axis('ds').reset_index()
    
    # label 결측치에 2를 할당합니다.
    filtered_df['label'] = filtered_df['label'].fillna(2)
    
    # 인덱스 재설정
    filtered_df = filtered_df.reset_index(drop=True)

    for feature in features:
        # 결측치가 아닌 값들에 대한 마스크를 생성합니다.
        mask = ~np.isnan(filtered_df[feature])  
        if mask.sum() > 0:  # NaN이 아닌 값이 있는지 확인합니다.
            fig, ax = plt.subplots(figsize=(10, 6))
            sc = ax.scatter(filtered_df['ds'].values[mask], filtered_df[feature].values[mask], c=filtered_df['label'].values[mask], cmap='bwr')
            ax.set_xlabel('Date')
            ax.set_ylabel('Value')
            ax.set_title(f'Disk {disk_id} - Time Series of {feature}')
            ax.legend(*sc.legend_elements(), title="Labels")
            plt.show()
        else:
            print(f"No non-missing data for feature {feature}.")
# Out:
# C:\Users\passion\AppData\Local\Temp/ipykernel_13876/574790240.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['ds'] = pd.to_datetime(filtered_df['ds'], format='%Y%m%d')
# No non-missing data for feature r_12.
# No non-missing data for feature n_171.
# No non-missing data for feature r_171.
# No non-missing data for feature n_172.
# No non-missing data for feature r_172.
# No non-missing data for feature r_174.
# No non-missing data for feature n_184.
# No non-missing data for feature r_184.
# No non-missing data for feature r_187.
# No non-missing data for feature r_188.
# No non-missing data for feature n_190.
# No non-missing data for feature r_190.
# No non-missing data for feature r_195.
# No non-missing data for feature r_197.
# No non-missing data for feature r_198.
# No non-missing data for feature r_199.

# %%
null_counts = filtered_df.isnull().sum()
print(null_counts)
# Out:
# ds          0
# disk_id     0
# r_1         0
# n_5         0
# r_5         0
# r_9         0
# r_12       76
# n_171      76
# r_171      76
# n_172      76
# r_172      76
# n_173       0
# r_174      76
# n_180       0
# r_180       0
# n_184      76
# r_184      76
# r_187      76
# r_188      76
# n_190      76
# r_190      76
# r_194       0
# r_195      76
# n_196       0
# r_196       0
# r_197      76
# r_198      76
# r_199      76
# n_175       0
# r_175       0
# label       0
# dtype: int64

# %%
missing_dates = filtered_df[filtered_df[feature].isnull()]['ds']
print("Missing Dates:")
for date in missing_dates:
    print(date)
# Out:
# Missing Dates:

# %%
filtered_df
# Out:
#            ds  disk_id           r_1   n_5  r_5      r_9  r_12  n_171  r_171  \
# 0  2019-01-01     1323  4.294967e+09  98.0  0.0  38721.0   NaN    NaN    NaN
# 1  2019-01-02     1323  4.294967e+09  98.0  0.0  38745.0   NaN    NaN    NaN
# 2  2019-01-03     1323  4.294967e+09  98.0  0.0  38769.0   NaN    NaN    NaN
# 3  2019-01-04     1323  4.294967e+09  98.0  0.0  38793.0   NaN    NaN    NaN
# 4  2019-01-05     1323  4.294967e+09  98.0  0.0  38817.0   NaN    NaN    NaN
# ..        ...      ...           ...   ...  ...      ...   ...    ...    ...
# 71 2019-03-13     1323  4.294967e+09  98.0  0.0  40417.0   NaN    NaN    NaN
# 72 2019-03-14     1323  4.294967e+09  98.0  0.0  40441.0   NaN    NaN    NaN
# 73 2019-03-15     1323  4.294967e+09  98.0  0.0  40465.0   NaN    NaN    NaN
# 74 2019-03-16     1323  4.294967e+09  98.0  0.0  40489.0   NaN    NaN    NaN
# 75 2019-03-17     1323  4.294967e+09  98.0  0.0  40513.0   NaN    NaN    NaN
#
#     n_172  r_172  n_173  r_174  n_180         r_180  n_184  r_184  r_187  \
# 0     NaN    NaN   70.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
# 1     NaN    NaN   70.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
# 2     NaN    NaN   70.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
# 3     NaN    NaN   70.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
# 4     NaN    NaN   70.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
# ..    ...    ...    ...    ...    ...           ...    ...    ...    ...
# 71    NaN    NaN   69.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
# 72    NaN    NaN   69.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
# 73    NaN    NaN   69.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
# 74    NaN    NaN   69.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
# 75    NaN    NaN   69.0    NaN  130.0  4.294967e+09    NaN    NaN    NaN
#
#     r_188  n_190  r_190  r_194  r_195  n_196  r_196  r_197  r_198  r_199  \
# 0     NaN    NaN    NaN   13.0    NaN  100.0    0.0    NaN    NaN    NaN
# 1     NaN    NaN    NaN   16.0    NaN  100.0    0.0    NaN    NaN    NaN
# 2     NaN    NaN    NaN   16.0    NaN  100.0    0.0    NaN    NaN    NaN
# 3     NaN    NaN    NaN   15.0    NaN  100.0    0.0    NaN    NaN    NaN
# 4     NaN    NaN    NaN   15.0    NaN  100.0    0.0    NaN    NaN    NaN
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 71    NaN    NaN    NaN   13.0    NaN  100.0    0.0    NaN    NaN    NaN
# 72    NaN    NaN    NaN   13.0    NaN  100.0    0.0    NaN    NaN    NaN
# 73    NaN    NaN    NaN   13.0    NaN  100.0    0.0    NaN    NaN    NaN
# 74    NaN    NaN    NaN   13.0    NaN  100.0    0.0    NaN    NaN    NaN
# 75    NaN    NaN    NaN   13.0    NaN  100.0    0.0    NaN    NaN    NaN
#
#     n_175         r_175  label
# 0   100.0  9.754096e+11      0
# 1   100.0  9.755037e+11      0
# 2   100.0  9.755978e+11      0
# 3   100.0  9.793263e+11      0
# 4   100.0  9.794203e+11      0
# ..    ...           ...    ...
# 71  100.0  1.018424e+12      0
# 72  100.0  1.018518e+12      0
# 73  100.0  1.022246e+12      0
# 74  100.0  1.022340e+12      0
# 75  100.0  1.022434e+12      0
#
# [76 rows x 31 columns]
