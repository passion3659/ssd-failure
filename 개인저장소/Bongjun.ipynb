# %%
import pandas as pd
import numpy as np
from pycaret.classification import *

# %%
df1 = pd.DataFrame()
for chunk in pd.read_csv("../ssd_data/combined_data/combined_df01.csv", chunksize=1000000):
    df1 = pd.concat([df1, chunk], ignore_index=True)
df1
# Out:
#           disk_id        ds model    n_1  r_1    n_5  r_5    n_9      r_9  \
# 0             100  20190101   MB2    NaN  NaN  100.0  0.0   96.0  20012.0
# 1          100034  20190101   MC1  100.0  0.0  100.0  0.0  100.0  10792.0
# 2          100035  20190101   MC1  100.0  0.0  100.0  0.0  100.0  10793.0
# 3           10005  20190101   MB1    NaN  NaN  100.0  0.0   99.0   4600.0
# 4          100055  20190101   MC1  100.0  0.0  100.0  0.0  100.0   6754.0
# ...           ...       ...   ...    ...  ...    ...  ...    ...      ...
# 12667762    99951  20190131   MA2    NaN  NaN  100.0  0.0  100.0  32834.0
# 12667763    99957  20190131   MA2    NaN  NaN  100.0  0.0  100.0  32884.0
# 12667764    99962  20190131   MA2    NaN  NaN  100.0  0.0  100.0  32883.0
# 12667765    99980  20190131   MC1  100.0  0.0  100.0  0.0  100.0   3416.0
# 12667766    99982  20190131   MA2    NaN  NaN  100.0  0.0  100.0  37458.0
#
#            n_12  ...  n_233  n_241         r_241  n_242         r_242  r_244  \
# ...

# %%
model_list = ['MA1','MA2','MB1','MB2','MC1','MC2']
for model in model_list:
    df=df1[df1['model']==model].reset_index().copy()
    df.to_csv(f'../ssd_data/preprocessed_data/df_01_{model}.csv',index=False)

# %%
df2 = pd.DataFrame()
for chunk in pd.read_csv("../ssd_data/combined_data/combined_df02.csv", chunksize=1000000):
    df2 = pd.concat([df2, chunk], ignore_index=True)
df2
# Out:
#           disk_id        ds model    n_1  r_1    n_5  r_5    n_9      r_9  \
# 0          100000  20190201   MC1  100.0  0.0  100.0  0.0  100.0  12983.0
# 1          100005  20190201   MC1  100.0  0.0  100.0  0.0  100.0  12984.0
# 2          100013  20190201   MA2    NaN  NaN  100.0  0.0  100.0  26369.0
# 3          100037  20190201   MC1  100.0  0.0  100.0  0.0  100.0   6794.0
# 4          100064  20190201   MA2    NaN  NaN  100.0  0.0  100.0  29674.0
# ...           ...       ...   ...    ...  ...    ...  ...    ...      ...
# 11371379    99914  20190228   MA2    NaN  NaN  100.0  0.0  100.0  35485.0
# 11371380    99957  20190228   MA2    NaN  NaN  100.0  0.0  100.0  33552.0
# 11371381     9997  20190228   MB2    NaN  NaN  100.0  0.0   95.0  21651.0
# 11371382     9997  20190228   MB1    NaN  NaN  100.0  0.0   97.0  14755.0
# 11371383    99987  20190228   MC1  100.0  0.0  100.0  0.0  100.0   4088.0
#
#            n_12  ...  n_233  n_241         r_241  n_242         r_242  r_244  \
# ...

# %%
df3 = pd.DataFrame()
for chunk in pd.read_csv("../ssd_data/combined_data/combined_df03.csv", chunksize=1000000):
    df3 = pd.concat([df3, chunk], ignore_index=True)
df3
# Out:
#           disk_id        ds model    n_1  r_1    n_5  r_5    n_9      r_9  \
# 0          100005  20190301   MA2    NaN  NaN  100.0  0.0  100.0  31192.0
# 1          100024  20190301   MC1  100.0  0.0  100.0  2.0  100.0  14736.0
# 2          100031  20190301   MC1  100.0  0.0  100.0  1.0  100.0  12208.0
# 3           10005  20190301   MC1  100.0  0.0  100.0  0.0  100.0   4084.0
# 4          100057  20190301   MA2    NaN  NaN  100.0  2.0  100.0  40465.0
# ...           ...       ...   ...    ...  ...    ...  ...    ...      ...
# 12658443    99979  20190331   MA2    NaN  NaN  100.0  0.0  100.0  38865.0
# 12658444    99980  20190331   MC1  100.0  0.0  100.0  0.0  100.0   4832.0
# 12658445    99988  20190331   MA2    NaN  NaN  100.0  0.0  100.0  38873.0
# 12658446    99989  20190331   MC1  100.0  0.0  100.0  0.0  100.0   4832.0
# 12658447     9999  20190331   MB1    NaN  NaN  100.0  0.0   96.0  15499.0
#
#            n_12  ...  n_233  n_241         r_241  n_242         r_242  r_244  \
# ...

# %%
model_list = ['MA1','MA2','MB1','MB2','MC1','MC2']
for model in model_list:
    df=df3[df3['model']==model].reset_index().copy()
    df.to_csv(f'../ssd_data/preprocessed_data/df_03_{model}.csv',index=False)

# %%
df4 = pd.DataFrame()
for chunk in pd.read_csv("../ssd_data/combined_data/combined_df04.csv", chunksize=1000000):
    df4 = pd.concat([df4, chunk], ignore_index=True)
df4
# Out:
#         disk_id        ds model    n_1           r_1    n_5     r_5    n_9  \
# 0             1  20190501   MB2    NaN           NaN  100.0     0.0   95.0
# 1          1000  20190501   MA1  130.0  4.294967e+09   96.0     0.0  100.0
# 2         10000  20190501   MB2    NaN           NaN  100.0     0.0   95.0
# 3        100004  20190501   MA2    NaN           NaN  100.0     0.0  100.0
# 4         10001  20190501   MB2    NaN           NaN  100.0     0.0   95.0
# ...         ...       ...   ...    ...           ...    ...     ...    ...
# 118281    27061  20190501   MC1  100.0  0.000000e+00  100.0     0.0  100.0
# 118282    27078  20190501   MB1    NaN           NaN  100.0     0.0   99.0
# 118283    27081  20190501   MA1  130.0  4.294967e+09   98.0     1.0  100.0
# 118284    27085  20190501   MA2    NaN           NaN   73.0  2040.0  100.0
# 118285    27093  20190501   MC1  100.0  0.000000e+00  100.0     0.0  100.0
#
# ...

# %%
df5 = pd.DataFrame()
for chunk in pd.read_csv("../ssd_data/combined_data/combined_df05.csv", chunksize=1000000):
    df5 = pd.concat([df5, chunk], ignore_index=True)
df5
# Out:
#           disk_id        ds model    n_1           r_1    n_5  r_5    n_9  \
# 0               1  20190501   MB2    NaN           NaN  100.0  0.0   95.0
# 1            1000  20190501   MA1  130.0  4.294967e+09   96.0  0.0  100.0
# 2           10000  20190501   MB2    NaN           NaN  100.0  0.0   95.0
# 3          100004  20190501   MA2    NaN           NaN  100.0  0.0  100.0
# 4           10001  20190501   MB2    NaN           NaN  100.0  0.0   95.0
# ...           ...       ...   ...    ...           ...    ...  ...    ...
# 12385840    99968  20190531   MC1  100.0  0.000000e+00  100.0  0.0  100.0
# 12385841    99970  20190531   MC1  100.0  0.000000e+00  100.0  0.0  100.0
# 12385842    99973  20190531   MA2    NaN           NaN  100.0  0.0  100.0
# 12385843    99973  20190531   MC1  100.0  0.000000e+00  100.0  0.0  100.0
# 12385844    99984  20190531   MA2    NaN           NaN  100.0  0.0  100.0
#
#               r_9   n_12  ...  n_233  n_241         r_241  n_242  \
# ...

# %%
model_list = ['MA1','MA2','MB1','MB2','MC1','MC2']
for model in model_list:
    df=df5[df5['model']==model].reset_index().copy()
    df.to_csv(f'../ssd_data/preprocessed_data/df_05_{model}.csv',index=False)

# %%
df6 = pd.DataFrame()
for chunk in pd.read_csv("../ssd_data/combined_data/combined_df06.csv", chunksize=1000000):
    df6 = pd.concat([df6, chunk], ignore_index=True)
df6
# Out:
#           disk_id        ds model    n_1  r_1    n_5  r_5    n_9      r_9  \
# 0               0  20190601   MA2    NaN  NaN  100.0  2.0  100.0  44448.0
# 1          100010  20190601   MA2    NaN  NaN  100.0  0.0  100.0  29234.0
# 2          100012  20190601   MA2    NaN  NaN  100.0  0.0  100.0  29234.0
# 3           10002  20190601   MA2    NaN  NaN  100.0  0.0  100.0  33647.0
# 4          100035  20190601   MA2    NaN  NaN  100.0  0.0  100.0  27130.0
# ...           ...       ...   ...    ...  ...    ...  ...    ...      ...
# 11267731    99953  20190630   MA2    NaN  NaN  100.0  0.0  100.0  36391.0
# 11267732    99953  20190630   MC1  100.0  0.0  100.0  1.0  100.0  16936.0
# 11267733    99974  20190630   MC1  100.0  1.0  100.0  1.0  100.0  16960.0
# 11267734    99975  20190630   MC1  100.0  0.0  100.0  0.0  100.0  16960.0
# 11267735    99983  20190630   MA2    NaN  NaN  100.0  0.0  100.0  41046.0
#
#            n_12  ...  n_233  n_241      r_241  n_242      r_242  r_244  n_175  \
# ...

# %%
import os
import pandas as pd
#, 'MA2', 'MB1', 'MB2', 'MC1', 'MC2'
model_list = ['MA1']
output_folder = '../ssd_data/preprocessed_data'

# model_list의 각 모델에 대해 반복
for model in model_list:
    output_filename = f'../ssd_data/combined_by_diskmodel/combined_{model}.csv'
    
    # 빈 데이터프레임 생성
    merged_data = pd.DataFrame()

    # 모델 이름으로 끝나는 .csv 파일 목록 가져오기
    csv_files = [file for file in os.listdir(output_folder) if file.endswith(f'{model}.csv')]

    # .csv 파일들을 순회하며 데이터프레임에 추가
    for file in csv_files:
        file_path = os.path.join(output_folder, file)
        df = pd.read_csv(file_path)
        if 'r_211' in df.columns:
            del(df['r_211'])
        merged_data = pd.concat([merged_data, df],ignore_index=True)

    # 병합된 데이터프레임을 CSV 파일로 저장
    merged_data.to_csv(output_filename, index=False)

# %%
import pandas as pd

MA1 = pd.DataFrame()
for chunk in pd.read_csv("../ssd_data/combined_by_diskmodel/combined_MA1.csv", chunksize=1000000):
    MA1 = pd.concat([MA1, chunk], ignore_index=True)
MA1
# Out:
#             index  disk_id        ds model    n_1           r_1   n_5  r_5  \
# 0              45    10045  20190101   MA1  130.0  4.294967e+09  97.0  0.0
# 1              50    10048  20190101   MA1  130.0  4.294967e+09  96.0  0.0
# 2              69    10066  20190101   MA1  130.0  4.294967e+09  96.0  0.0
# 3              86    10083  20190101   MA1  130.0  4.294967e+09  98.0  0.0
# 4             129    10122  20190101   MA1  130.0  4.294967e+09  97.0  0.0
# ...           ...      ...       ...   ...    ...           ...   ...  ...
# 4744310  11267559     9838  20190630   MA1  130.0  4.294967e+09  97.0  0.0
# 4744311  11267567     9842  20190630   MA1  130.0  5.896511e+06  98.0  0.0
# 4744312  11267600     9878  20190630   MA1  130.0  4.294967e+09  96.0  0.0
# 4744313  11267700     9970  20190630   MA1  130.0  4.294967e+09  96.0  0.0
# 4744314  11267707     9974  20190630   MA1  130.0  4.294967e+09  96.0  0.0
#
# ...

# %%
del(MA1['index'])

# %%
# null값이 있는 열을 제거하는 코드
def remove_null_columns(df):
    # null인 컬럼을 확인하고, 모든 값이 null인 컬럼을 찾습니다.
    null_columns = df.columns[df.isnull().all()]
    
    # 모든 값이 null인 컬럼을 DataFrame에서 제거합니다.
    df = df.drop(null_columns, axis=1)
    
    return df

# %%
# 하나의 unique한 값으로만 이루어진 컬럼을 제거하는 코드
def remove_single_value_columns(df):
    single_value_cols = []
    for col in df.columns:
        unique_values = df[col].nunique()
        if unique_values == 1:
            single_value_cols.append(col)

    df_filtered = df.drop(single_value_cols, axis=1)
    return df_filtered

# %%
MA1 = remove_null_columns(MA1)
MA1 = remove_single_value_columns(MA1)

# %%
MA1=MA1.fillna(0)

# %%
# 라벨이 1인 행을 필터링합니다.
selected_disk_model_1 = MA1[MA1['label'] == 1]

# 모델, disk_id, 그리고 날짜 순으로 정렬합니다.
selected_disk_model_1 = selected_disk_model_1.sort_values(by=['disk_id', 'ds'])

# disk_id와 model 열만을 선택하여 새로운 데이터 프레임에 저장합니다.
selected_disk_model_1 = selected_disk_model_1[['disk_id']].drop_duplicates().reset_index(drop=True)

# 결과 데이터 프레임을 출력합니다.
print(selected_disk_model_1)
# Out:
#      disk_id
# 0        520
# 1       1156
# 2       1224
# 3       1225
# 4       1230
# ..       ...
# 270    42763
# 271    42764
# 272    42767
# 273    42815
# 274    42824
#
# [275 rows x 1 columns]

# %%
# disk_ids 데이터프레임에 있는 disk_id와 일치하는 행을 MA1 데이터프레임에서 불러옴
selected_label_1 = MA1[MA1['disk_id'].isin(selected_disk_model_1['disk_id'])]

# ds 컬럼에 따라 정렬
selected_label_1 = selected_label_1.sort_values(by='ds')

# 결과 출력
selected_label_1
# Out:
#          disk_id        ds           r_1   n_5  r_5      r_9  r_12  n_171  \
# 73          1224  20190101  4.294967e+09  98.0  0.0  40531.0  27.0  100.0
# 15887       1574  20190101  4.294967e+09  93.0  0.0  45675.0  36.0  100.0
# 15898      16147  20190101  4.294967e+09  98.0  0.0  40766.0  36.0  100.0
# 16266      28267  20190101  4.294967e+09  95.0  0.0  46339.0  41.0  100.0
# 16745       4805  20190101  4.294967e+09  98.0  0.0  38250.0  54.0  100.0
# ...          ...       ...           ...   ...  ...      ...   ...    ...
# 4728372    21596  20190630  4.294967e+09  98.0  0.0  44478.0  30.0  100.0
# 4728775    36331  20190630  4.294967e+09  98.0  0.0  42817.0   0.0    0.0
# 4728831    37801  20190630  4.294967e+09  98.0  0.0  44870.0  38.0  100.0
# 4726972    11886  20190630  4.294967e+09  94.0  0.0  50427.0  40.0  100.0
# 4744124    42764  20190630  4.294967e+09  98.0  4.0  44850.0  41.0  100.0
#
#          r_171  n_172  ...  r_194         r_195  n_196  r_196  r_197  r_198  \
# ...

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# 결과를 저장할 빈 데이터프레임 생성
processed_label_1 = pd.DataFrame()

# tqdm을 사용하여 진행 상황 표시
for disk_id in tqdm(list(selected_disk_model_1['disk_id'])):
    # 특정 disk_id에 대한 데이터 추출
    subset = selected_label_1[(selected_label_1['disk_id'] == disk_id)].copy()
    
    # label이 1인 인덱스 찾기
    label_one_indices = subset.index[subset['label'] == 1].tolist()
    
    # label이 1인 날짜 이전 30일을 찾아서 label을 1로 설정
    for index in label_one_indices:
        # 이전 30일의 인덱스를 찾음 (최소 인덱스를 고려)
        start_index = max(index - 30, subset.index.min())
        subset.loc[start_index:index, 'label'] = 1
    
    # 결과 데이터에 추가
    processed_label_1 = pd.concat([processed_label_1, subset])

# 최종 전처리된 데이터
processed_label_1
# Out:
# 100%|██████████| 275/275 [00:00<00:00, 363.02it/s]
#          disk_id        ds           r_1   n_5  r_5      r_9  r_12  n_171  \
# 821858       520  20190130  9.376596e+08  96.0  0.0  38191.0  27.0  100.0
# 858376       520  20190131  1.624577e+09  96.0  0.0  38215.0  27.0  100.0
# 873871       520  20190201  2.014090e+09  96.0  0.0  38239.0  27.0  100.0
# 907339       520  20190202  2.812968e+09  96.0  0.0  38263.0  27.0  100.0
# 943568       520  20190203  3.442008e+09  96.0  0.0  38287.0  27.0  100.0
# ...          ...       ...           ...   ...  ...      ...   ...    ...
# 4643066    42824  20190626  4.294967e+09  94.0  0.0  48860.0  46.0  100.0
# 4668803    42824  20190627  4.294967e+09  94.0  0.0  48884.0  46.0  100.0
# 4694939    42824  20190628  4.294967e+09  94.0  0.0  48908.0  46.0  100.0
# 4702639    42824  20190629  4.294967e+09  94.0  0.0  48932.0  46.0  100.0
# 4735585    42824  20190630  4.294967e+09  94.0  0.0  48955.0  46.0  100.0
#
# ...

# %%
import random

# 시드 값을 설정합니다.
random.seed(42)

# 라벨이 1인 행을 필터링합니다.
selected_disk_model_0 = MA1[MA1['label'] == 0]

# disk_id만 추출
selected_disk_model_0 = selected_disk_model_0['disk_id'].drop_duplicates()
selected_disk_model_0 = list(selected_disk_model_0)
selected_disk_model_0

# 275개를 랜덤하게 선택
selected_disk_model_0 = random.sample(selected_disk_model_0, 275)

# %%
# disk_ids 데이터프레임에 있는 disk_id와 일치하는 행을 MA1 데이터프레임에서 불러옴
selecetd_label_0= MA1[MA1['disk_id'].isin(selected_disk_model_0)]

# ds 컬럼에 따라 정렬
selecetd_label_0= selecetd_label_0.sort_values(by='ds')

# 결과 출력
selecetd_label_0
# Out:
#          disk_id        ds           r_1   n_5  r_5      r_9  r_12  n_171  \
# 37         11021  20190101  4.294967e+09  95.0  0.0  46679.0  33.0  100.0
# 17089      14869  20190101  4.294967e+09  97.0  0.0  37640.0   0.0    0.0
# 17219      19415  20190101  4.294967e+09  98.0  0.0  36844.0  41.0  100.0
# 17261      20740  20190101  4.294967e+09  98.0  0.0  37172.0  41.0  100.0
# 17335      22839  20190101  4.294967e+09  98.0  0.0  40441.0  74.0  100.0
# ...          ...       ...           ...   ...  ...      ...   ...    ...
# 4728727    34800  20190630  4.294967e+09  97.0  0.0  42525.0   0.0    0.0
# 4728745    35176  20190630  4.294967e+09  98.0  0.0  44852.0  51.0  100.0
# 4728842    38166  20190630  4.294967e+09  98.0  2.0  42603.0   0.0    0.0
# 4731751    24294  20190630  4.294967e+09  92.0  0.0  50139.0  25.0  100.0
# 4744139     4473  20190630  4.294967e+09  98.0  0.0  44637.0  78.0  100.0
#
#          r_171  n_172  ...  r_194         r_195  n_196  r_196  r_197  r_198  \
# ...

# %%
# final_df와 final_df2를 합칩니다.
final_df = pd.concat([processed_label_1, selecetd_label_0])

# model, disk_id, date를 기준으로 그룹화하고 shuffle합니다.
grouped = final_df.groupby(['disk_id'])
shuffled_groups = random.sample(list(grouped), len(grouped))

# 진행 상황을 표시하기 위해 tqdm 사용
shuffled_df = pd.DataFrame()
for _, group in tqdm(shuffled_groups):
    shuffled_df = pd.concat([shuffled_df, group])

# 최종 결과를 출력합니다.
shuffled_df
# Out:
# C:\Users\choib\AppData\Local\Temp\ipykernel_41072\277537219.py:6: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   shuffled_groups = random.sample(list(grouped), len(grouped))
# ...
# 100%|██████████| 548/548 [00:01<00:00, 336.47it/s]
#          disk_id        ds           r_1   n_5  r_5      r_9  r_12  n_171  \
# 5372       12421  20190101  4.294967e+09  98.0  0.0  40821.0  38.0  100.0
# 53056      12421  20190102  4.294967e+09  98.0  0.0  40845.0  38.0  100.0
# 81970      12421  20190103  4.294967e+09  98.0  0.0  40869.0  38.0  100.0
# 106666     12421  20190104  4.294967e+09  98.0  0.0  40893.0  38.0  100.0
# 130818     12421  20190105  4.294967e+09  98.0  0.0  40916.0  38.0  100.0
# ...          ...       ...           ...   ...  ...      ...   ...    ...
# ...

# %%
shuffled_df.to_csv('../ssd_data/final_data/final_data_MA1.csv',index=False)

# %% [markdown]
# -----------------------여기까지-------------------------------------

# %% [markdown]
# ### pycaret

# %%
import pandas as pd
import numpy as np
from pycaret.classification import *

# 데이터프레임을 생성하여 PyCaret에 적합한 형태로 만듭니다.
data = shuffled_df.copy()  # shuffled_df를 data로 복사합니다.

# PyCaret 환경 초기화
exp = setup(data=data, target='label', train_size=0.8, session_id=42)

# 모델 비교
best_model = compare_models()

# 예측
predictions = predict_model(best_model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              00:18:17
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# </style>
# <table id="T_8ec16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ec16_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8ec16_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8ec16_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8ec16_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8ec16_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8ec16_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8ec16_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8ec16_level0_col7" class="col_heading level0 col7" >MCC</th>
# ...

# %%
print(best_model)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=42, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
best_tune = tune_model(best_model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              00:28:49
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_bb86d_row10_col0, #T_bb86d_row10_col1, #T_bb86d_row10_col2, #T_bb86d_row10_col3, #T_bb86d_row10_col4, #T_bb86d_row10_col5, #T_bb86d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bb86d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb86d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bb86d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bb86d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bb86d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bb86d_level0_col4" class="col_heading level0 col4" >F1</th>
# ...

# %%
evaluate_model(best_tune)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best_tune)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7203d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7203d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7203d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7203d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7203d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7203d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7203d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7203d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7203d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7203d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7203d_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
# ...

# %% [markdown]
# ### 5 window 전처리

# %%
shuffled_df=shuffled_df.reset_index()

# %%
del(shuffled_df['index'])

# %%
shuffled_df
# Out:
#        disk_id        ds model    n_1   r_1    n_5   r_5    n_9      r_9  \
# 0        65510  20190101   MC1  100.0   0.0  100.0   0.0  100.0   9742.0
# 1        65510  20190102   MC1  100.0   0.0  100.0   0.0  100.0   9766.0
# 2        65510  20190103   MC1  100.0   0.0  100.0   0.0  100.0   9790.0
# 3        65510  20190104   MC1  100.0   0.0  100.0   0.0  100.0   9814.0
# 4        65510  20190105   MC1  100.0   0.0  100.0   0.0  100.0   9838.0
# ...        ...       ...   ...    ...   ...    ...   ...    ...      ...
# 60720   139179  20190224   MC1  100.0  29.0  100.0  10.0  100.0  10675.0
# 60721   139179  20190225   MC1  100.0  35.0  100.0  10.0  100.0  10699.0
# 60722   139179  20190226   MC1  100.0  35.0  100.0  10.0  100.0  10723.0
# 60723   139179  20190227   MC1  100.0  35.0  100.0  10.0  100.0  10747.0
# 60724   139179  20190228   MC1  100.0  38.0  100.0  10.0  100.0  10771.0
#
#         n_12  ...  n_233  n_241  r_241  n_242  r_242  r_244  n_175  r_175  \
# ...

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# 데이터 프레임 예시 (shuffled_df 라는 데이터 프레임이 있다고 가정)
# shuffled_df = pd.DataFrame(...)

# model과 disk_id별로 unique한 그룹을 찾습니다.
grouped = shuffled_df.groupby(['model', 'disk_id'])

# lag window size
window_size = 5

# 결과를 저장할 빈 데이터프레임을 만듭니다.
result = pd.DataFrame()

# tqdm을 사용하여 진행 상태를 표시합니다.
for name, group in tqdm(grouped, desc="Processing groups"):
    # 변수들에 대한 lag feature를 생성합니다. (4번째부터 마지막에서 두 번째 열까지)
    features = group.iloc[:, 3:-1].values
    labels = group.iloc[:, -1].values
    dates = group.iloc[:, 1].values
    lag_features = []
    lag_labels = []
    lag_dates = []
    
    # window를 이동시키며 lag feature를 만듭니다.
    for i in range(len(features) - window_size + 1):
        window = features[i:i + window_size].flatten()
        lag_features.append(window)
        lag_labels.append(labels[i + window_size - 1])
        lag_dates.append(dates[i + window_size - 1])
    
    # 데이터프레임 형태로 변환합니다.
    num_features = len(group.columns) - 4
    columns = [f'var_{j}_lag_{i}' for j in range(1, num_features+1) for i in range(1, window_size+1)]
    lag_df = pd.DataFrame(lag_features, columns=columns)
    
    # 기존 정보를 포함시킵니다.
    lag_df['model'] = name[0]
    lag_df['disk_id'] = name[1]
    lag_df['date'] = lag_dates  # 날짜를 추가합니다.
    
    # Label을 추가합니다.
    lag_df['label'] = lag_labels
    
    # 결과 데이터프레임에 추가합니다.
    result = pd.concat([result, lag_df])

# 결과를 출력합니다.
print(result)
# Out:
# Processing groups: 100%|██████████| 1192/1192 [00:26<00:00, 45.37it/s]
#     var_1_lag_1   var_1_lag_2  var_1_lag_3  var_1_lag_4  var_1_lag_5  \
# 0         130.0  4.294967e+09         93.0          2.0        100.0
# 1         130.0  4.294967e+09         93.0          2.0        100.0
# 2         130.0  4.294967e+09         93.0          2.0        100.0
# 3         130.0  4.294967e+09         93.0          2.0        100.0
# 4         130.0  4.294967e+09         93.0          2.0        100.0
# ..          ...           ...          ...          ...          ...
# 50        100.0  0.000000e+00        100.0          0.0        100.0
# 51        100.0  0.000000e+00        100.0          0.0        100.0
# 52        100.0  0.000000e+00        100.0          0.0        100.0
# 53        100.0  0.000000e+00        100.0          0.0        100.0
# 54        100.0  0.000000e+00        100.0          0.0        100.0
#
# ...

# %% [markdown]
# ### 30일 이전을 label = 1 로

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# result 데이터프레임 예시
# 'model', 'disk_id', 'date', 'features...', 'label'

# model, disk_id 조합을 가져옴
unique_combinations = result[['model', 'disk_id']].drop_duplicates().values.tolist()

# 결과를 저장할 빈 데이터프레임 생성
processed_data = pd.DataFrame()

# tqdm을 사용하여 진행 상황 표시
for model, disk_id in tqdm(unique_combinations):
    # 특정 model, disk_id에 대한 데이터 추출
    subset = result[(result['model'] == model) & (result['disk_id'] == disk_id)].copy()
    
    # label이 1인 인덱스 찾기
    label_one_indices = subset.index[subset['label'] == 1].tolist()
    
    # label이 1인 날짜 이전 30일을 찾아서 label을 1로 설정
    for index in label_one_indices:
        # 이전 30일의 인덱스를 찾음 (최소 인덱스를 고려)
        start_index = max(index - 30, subset.index.min())
        subset.loc[start_index:index, 'label'] = 1
    
    # 결과 데이터에 추가
    processed_data = pd.concat([processed_data, subset])

# 최종 전처리된 데이터
print(processed_data)
# Out:
# 100%|██████████| 1176/1176 [00:24<00:00, 47.71it/s]
#     var_1_lag_1   var_1_lag_2  var_1_lag_3  var_1_lag_4  var_1_lag_5  \
# 0         130.0  4.294967e+09         93.0          2.0        100.0
# 1         130.0  4.294967e+09         93.0          2.0        100.0
# 2         130.0  4.294967e+09         93.0          2.0        100.0
# 3         130.0  4.294967e+09         93.0          2.0        100.0
# 4         130.0  4.294967e+09         93.0          2.0        100.0
# ..          ...           ...          ...          ...          ...
# 50        100.0  0.000000e+00        100.0          0.0        100.0
# 51        100.0  0.000000e+00        100.0          0.0        100.0
# 52        100.0  0.000000e+00        100.0          0.0        100.0
# 53        100.0  0.000000e+00        100.0          0.0        100.0
# 54        100.0  0.000000e+00        100.0          0.0        100.0
#
#     var_2_lag_1  var_2_lag_2  var_2_lag_3  var_2_lag_4  var_2_lag_5  ...  \
# ...

# %%
#전처리 완료된 데이터(1~2월)
processed_data.to_csv('../ssd_data/preprocessed_data/preprocessed_data.csv')

# %% [markdown]
# ### 간단한 RandomForest 코드

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from tqdm import tqdm

# 이전에 만든 lag feature 데이터프레임 예시: processed_data
# 'model', 'disk_id', 'features...', 'label' 컬럼들을 포함

# 각 model, disk_id별로 분리하여 모델 학습 및 예측
unique_combinations = processed_data[['model', 'disk_id']].drop_duplicates().values.tolist()

# 각 조합별 정확도를 저장할 리스트
accuracies = []

# tqdm을 사용하여 진행 상황 표시
for model, disk_id in tqdm(unique_combinations):
    # 특정 model, disk_id에 대한 데이터 추출
    subset = processed_data[(processed_data['model'] == model) & (processed_data['disk_id'] == disk_id)]
    
    # NaN 값을 0으로 대체
    subset = subset.fillna(0)
    
    # 시간 순서를 유지한 상태로 train-test 분할 (예: 앞 80%는 train, 뒤 20%는 test)
    train_size = int(len(subset) * 0.8)
    train_data = subset[:train_size]
    test_data = subset[train_size:]
    
    # 만약 train_data 또는 test_data가 비어있다면, 해당 조합을 건너뜀
    if train_data.empty or test_data.empty:
        continue
    
    # Feature와 label 분리
    X_train = train_data.drop(['model', 'disk_id', 'label'], axis=1)
    y_train = train_data['label']
    X_test = test_data.drop(['model', 'disk_id', 'label'], axis=1)
    y_test = test_data['label']
    
    # RandomForest 모델 학습
    rf = RandomForestClassifier(random_state=42)
    rf.fit(X_train, y_train)
    
    # 예측
    y_pred = rf.predict(X_test)
    
    # 정확도 측정 및 저장
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)

# 전체 평균 정확도
mean_accuracy = sum(accuracies) / len(accuracies) if accuracies else 0
print(f"Mean Accuracy: {mean_accuracy}")
# Out:
# 100%|██████████| 1176/1176 [02:24<00:00,  8.11it/s]
# Mean Accuracy: 0.9571921341070275

# %%
# 전체 평균 정확도
mean_accuracy = sum(accuracies) / len(accuracies) if accuracies else 0
print(f"Mean Accuracy: {mean_accuracy}")
# Out:
# Mean Accuracy: 0.9571921341070275

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from tqdm import tqdm

# 이전에 만든 lag feature 데이터프레임 예시: processed_data
# 'model', 'disk_id', 'features...', 'label' 컬럼들을 포함

# 각 model, disk_id별로 분리하여 모델 학습 및 예측
unique_combinations = processed_data[['model', 'disk_id']].drop_duplicates().values.tolist()

# 각 조합별 평가 지표를 저장할 리스트
accuracies = []
f1_scores = []
precisions = []
recalls = []
aucs = []

# tqdm을 사용하여 진행 상황 표시
for model, disk_id in tqdm(unique_combinations):
    # 특정 model, disk_id에 대한 데이터 추출
    subset = processed_data[(processed_data['model'] == model) & (processed_data['disk_id'] == disk_id)]
    
    # NaN 값을 0으로 대체
    subset = subset.fillna(0)
    
    # 시간 순서를 유지한 상태로 train-test 분할 (예: 앞 80%는 train, 뒤 20%는 test)
    train_size = int(len(subset) * 0.8)
    train_data = subset[:train_size]
    test_data = subset[train_size:]
    
    # 만약 train_data 또는 test_data가 비어있다면, 해당 조합을 건너뜀
    if train_data.empty or test_data.empty:
        continue
    
    # Feature와 label 분리
    X_train = train_data.drop(['model', 'disk_id', 'label'], axis=1)
    y_train = train_data['label']
    X_test = test_data.drop(['model', 'disk_id', 'label'], axis=1)
    y_test = test_data['label']
    
    # RandomForest 모델 학습
    rf = RandomForestClassifier(random_state=42)
    rf.fit(X_train, y_train)
    
    # 예측
    y_pred = rf.predict(X_test)
    
    # 평가 지표 계산 및 저장
    accuracies.append(accuracy_score(y_test, y_pred))
    f1_scores.append(f1_score(y_test, y_pred, zero_division=0))
    precisions.append(precision_score(y_test, y_pred, zero_division=0))
    recalls.append(recall_score(y_test, y_pred, zero_division=0))
    
    # AUC를 계산하기 전에 테스트 데이터셋에 두 개 이상의 클래스(라벨)가 있는지 확인
    if len(set(y_test)) > 1 and hasattr(rf, "predict_proba"):
        y_pred_proba = rf.predict_proba(X_test)
        if y_pred_proba.shape[1] > 1:
            aucs.append(roc_auc_score(y_test, y_pred_proba[:, 1]))
        else:
            aucs.append(float('nan'))  # AUC를 계산할 수 없는 경우 NaN을 추가
    else:
        aucs.append(float('nan'))  # AUC를 계산할 수 없는 경우 NaN을 추가
# Out:
# 100%|██████████| 1176/1176 [06:42<00:00,  2.92it/s]
# Mean Accuracy: 0.9571921341070275
# Mean F1 Score: 0.06952972269809103
# Mean Precision: 0.06102192134107027
# Mean Recall: 0.09361702127659574
# Mean AUC: nan

# %%
# 전체 평균 평가 지표
mean_accuracy = sum(accuracies) / len(accuracies) if accuracies else 0
mean_f1_score = sum(f1_scores) / len(f1_scores) if f1_scores else 0
mean_precision = sum(precisions) / len(precisions) if precisions else 0
mean_recall = sum(recalls) / len(recalls) if recalls else 0
mean_auc = sum(aucs) / len(aucs) if aucs else 0

# 결과 출력
print(f"Mean Accuracy: {mean_accuracy}")
print(f"Mean F1 Score: {mean_f1_score}")
print(f"Mean Precision: {mean_precision}")
print(f"Mean Recall: {mean_recall}")
print(f"Mean AUC: {mean_auc}")
# Out:
# Mean Accuracy: 0.9571921341070275
# Mean F1 Score: 0.06952972269809103
# Mean Precision: 0.06102192134107027
# Mean Recall: 0.09361702127659574
# Mean AUC: nan

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(32, input_shape=(None, 10)))  # 10 is the dimensionality of input features.
model.add(Dense(1))

model.compile(optimizer='rmsprop', loss='mse')
